# %% [markdown]
# # Examples
#
# The below illustrates the way this code can be used to accomplish various common tasks.
#
# **Outputs can be written to a CSV file, a SQLite database, or both**. In the case of a SQLite database, if it does not yet exist, it will be automatically created, set up, and populated, so no experience with SQLite is necessary (until you want to query it for data, that is). One benefit of using the SQLite database is that unique indexes ensure that no duplicates are inserted. We handle this with CSVs less efficiently, by scanning over the CSV for duplicate IDs after we're done with the full output.
#
# The reason we have to work around duplicates at all is because of how the Regulations.gov API's pagination mechanism works (the reason: you get up to 20 pages per "query", each of which has up to 250 items. If you need more than 250x20 = 5000 items, you have to use a second "query", which is the same as the first, but filtered to a lastModifiedDate >= the maximum lastModifiedDate of the previous query. As a result, there will be repeated items. Unfortunately, this is necessary because there may be multiple items with the same lastModifiedDate).

# %% [markdown]
# # Get an instance of the CommentDownloader
#
# **This is required for all examples below**. You must have an API key, which you can get at https://open.gsa.gov/api/regulationsgov/#getting-started. The "DEMO_KEY" below is functional, but is limited to only 25 requests per hour, while a normal API key has up to 1,000 requests per hour.

# %%
from comments_downloader import CommentsDownloader
downloader = CommentsDownloader(api_key="DEMO_KEY")

# %% [markdown]
# Alternatively, if you don't want to hard-code your API key, you could do:
#
#     import getpass
#     from comments_downloader import CommentsDownloader
#
#     api_key = getpass.getpass("Enter API key")
#     downloader = CommentsDownloader(api_key)

# %% [markdown]
# # Q: How do I download all comments associated with a docket?

# %%
# We are outputting to both the database and the CSV here, but you can exclude either the db_filename or 
#     csv_filename parameters if you want to export to only one of them.
# Notice that the database is created automatically. If the database already existed, we would be appending to it, not replacing it.

downloader.gather_comments_by_docket("FDA-2021-N-0270", db_filename="my_database.db", csv_filename="my_csv.csv")
# Out:
# 2021-05-27 12:02:40: Getting documents associated with docket FDA-2021-N-0270...
#
# Found 1 documents...
# 2021-05-27 12:02:41: Inserting 1 records into database...
# 2021-05-27 12:02:41: Writing 1 records to document_headers_120240.csv...Done
# 2021-05-27 12:02:41: Removing any duplicates in the CSV...
# 2021-05-27 12:02:41: Done. Removed 0 duplicate rows from document_headers_120240.csv.
# 2021-05-27 12:02:41: Finished: approximately 1 documents collected
#
# Done----------------
#
# ******************************
# 2021-05-27 12:02:41: Getting comments for document FDA-2021-N-0270-0001...
#
# 2021-05-27 12:02:41: Getting objectId for document FDA-2021-N-0270-0001...Got it (0900006484a930da)
# 2021-05-27 12:02:41: Getting comment headers associated with document FDA-2021-N-0270-0001...
#
# Found 181 comments...
# 2021-05-27 12:02:42: Inserting 181 records into database...
# 2021-05-27 12:02:42: Writing 181 records to comment_headers_120241.csv...Done
# 2021-05-27 12:02:42: Removing any duplicates in the CSV...
# 2021-05-27 12:02:42: Done. Removed 0 duplicate rows from comment_headers_120241.csv.
# 2021-05-27 12:02:42: Finished: approximately 181 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:02:42: Getting comments associated with document FDA-2021-N-0270-0001...
#
# 2021-05-27 12:02:42: Gathering details for 181 comments...
# (Requests left: 900)
# 2021-05-27 12:03:21: Inserting 181 records into database...
# 2021-05-27 12:03:21: Writing 181 records to my_csv.csv...Done
# 2021-05-27 12:03:21: Finished: 181 comments collected
#
# Done getting all 181 comments for document FDA-2021-N-0270-0001----------------
#
# DONE retrieving all 181 comments from 1 document(s) for docket FDA-2021-N-0270----------------

# %% [markdown]
# ## Look at the data

# %%
# look at the data

# See readme for database schema. The comment details (including its plain-text) are in comments_detail
import pandas as pd
import sqlite3

conn = sqlite3.connect("my_database.db")
pd.read_sql_query("select * from comments_detail limit 5", conn)
# Out:
#               commentId agencyId                  category  city  \
# 0  FDA-2021-N-0270-0077      FDA  Drug Association - D0012  None
# 1  FDA-2021-N-0270-0151      FDA                      None  None
# 2  FDA-2021-N-0270-0052      FDA       Individual Consumer  None
# 3  FDA-2021-N-0270-0113      FDA     Drug Industry - C0022  None
# 4  FDA-2021-N-0270-0065      FDA       Individual Consumer  None
#
#                                              comment         commentOn  \
# 0  I have been T1D for 60 yrs. now. After about 4...  0900006484a930da
# 1  I am writing to support a recommendation to ap...  0900006484a930da
# 2  As a mom to identical twin boys and wife to a ...  0900006484a930da
# 3  As a parent of one child who is a Type 1 diabe...  0900006484a930da
# 4  I was diagnosed with Type 1 diabetes when I wa...  0900006484a930da
#
#     commentOnDocumentId        country docAbstract         docketId  ...  \
# 0  FDA-2021-N-0270-0001  United States        None  FDA-2021-N-0270  ...
# 1  FDA-2021-N-0270-0001  United States        None  FDA-2021-N-0270  ...
# 2  FDA-2021-N-0270-0001  United States        None  FDA-2021-N-0270  ...
# 3  FDA-2021-N-0270-0001  United States        None  FDA-2021-N-0270  ...
# 4  FDA-2021-N-0270-0001  United States        None  FDA-2021-N-0270  ...
#
#   restrictReasonType  stateProvinceRegion submitterRep submitterRepCityState  \
# 0               None                   TX         None                  None
# 1               None                   CA         None                  None
# 2               None                   CA         None                  None
# 3               None                   TX         None                  None
# 4               None                   CA         None                  None
#
#                            subtype                          title  \
# 0  Electronic Regulation from Form    Comment from Ann M Jenschke
# 1  Electronic Regulation from Form   Comment from Kevin O'Scanlon
# 2  Electronic Regulation from Form     Comment from Susan Sjolund
# 3  Electronic Regulation from Form  Comment from Jen Meisenheimer
# 4  Electronic Regulation from Form       Comment from Lona Albano
#
#      trackingNbr withdrawn   zip              sqltime
# 0  kol-px4s-8ss3         0  None  2021-05-27 16:03:21
# 1  kp4-bmwl-0drg         0  None  2021-05-27 16:03:21
# 2  kok-fogq-kwux         0  None  2021-05-27 16:03:21
# 3  kov-xxym-w9cm         0  None  2021-05-27 16:03:21
# 4  kok-tye2-0e33         0  None  2021-05-27 16:03:21
#
# [5 rows x 40 columns]

# %%
# look at header information for comments
pd.read_sql_query("select * from comments_header limit 5", conn)
# Out:
#               commentId agencyId       documentType      lastModifiedDate  \
# 0  FDA-2021-N-0270-0002      FDA  Public Submission  2021-04-01T20:31:47Z
# 1  FDA-2021-N-0270-0003      FDA  Public Submission  2021-04-12T16:29:37Z
# 2  FDA-2021-N-0270-0004      FDA  Public Submission  2021-04-12T16:31:21Z
# 3  FDA-2021-N-0270-0005      FDA  Public Submission  2021-04-20T19:42:30Z
# 4  FDA-2021-N-0270-0006      FDA  Public Submission  2021-04-20T19:46:27Z
#
#            objectId            postedDate                          title  \
# 0  0900006484a942e8  2021-04-01T04:00:00Z     Comment from Mark Atkinson
# 1  0900006484aa0b69  2021-04-12T04:00:00Z     Comment from Bodie Francis
# 2  0900006484aa0bf7  2021-04-12T04:00:00Z    Comment from THOMAS WEGESIN
# 3  0900006484aa5c46  2021-04-20T04:00:00Z  Comment from Ginger Patterson
# 4  0900006484aad502  2021-04-20T04:00:00Z     Comment from Kathryn Dancy
#
#    withdrawn              sqltime
# 0          0  2021-05-27 16:02:42
# 1          0  2021-05-27 16:02:42
# 2          0  2021-05-27 16:02:42
# 3          0  2021-05-27 16:02:42
# 4          0  2021-05-27 16:02:42

# %%
# look at header information for the docket's documents. Note that we don't download the documents' details in this process
pd.read_sql_query("select * from documents_header limit 5", conn)
# Out:
#              documentId        commentEndDate      commentStartDate  \
# 0  FDA-2021-N-0270-0001  2021-05-27T03:59:59Z  2021-04-01T04:00:00Z
#
#           docketId documentType    frDocNum      lastModifiedDate  \
# 0  FDA-2021-N-0270       Notice  2021-06708  2021-05-27T01:00:47Z
#
#            objectId            postedDate             subtype  \
# 0  0900006484a930da  2021-04-01T04:00:00Z  Advisory Committee
#
#                                                title  withdrawn  \
# 0  Endocrinologic and Metabolic Drugs Advisory Co...          0
#
#                sqltime
# 0  2021-05-27 16:02:41

# %%
conn.close()

# %% [markdown]
# # Q: How do I download all comments associated with *multiple* dockets?
#
# Links to dockets used below:
# * https://www.regulations.gov/docket/FDA-2009-N-0501
# * https://www.regulations.gov/docket/EERE-2019-BT-STD-0036
# * https://www.regulations.gov/docket/NHTSA-2019-0121

# %% [markdown]
# ## Into a database only
#
# Notice that the database is created automatically. If the database already existed, we would be appending to it, not replacing it

# %%
# you could add the csv_filename argument to export to both a database and a single CSV
my_dockets = ['FDA-2009-N-0501', 'EERE-2019-BT-STD-0036', 'NHTSA-2019-0121']

for docket_id in my_dockets:
    print(f"\n********************************\nSTARTING {docket_id}\n********************************")
    downloader.gather_comments_by_docket(docket_id, db_filename="my_database2.db")

print("\nDONE")
# Out:
# ********************************
# STARTING FDA-2009-N-0501
# ********************************
# 2021-05-27 12:06:01: Getting documents associated with docket FDA-2009-N-0501...
#
# Found 9 documents...
# 2021-05-27 12:06:01: Inserting 9 records into database...
# 2021-05-27 12:06:01: Writing 9 records to document_headers_120601.csv...Done
# 2021-05-27 12:06:01: Removing any duplicates in the CSV...
# 2021-05-27 12:06:01: Done. Removed 0 duplicate rows from document_headers_120601.csv.
# 2021-05-27 12:06:01: Finished: approximately 9 documents collected
#
# Done----------------
#
# ******************************
# 2021-05-27 12:06:01: Getting comments for document FDA-2009-N-0501-0011...
#
# 2021-05-27 12:06:01: Getting objectId for document FDA-2009-N-0501-0011...Got it (09000064845f4f11)
# 2021-05-27 12:06:02: Getting comment headers associated with document FDA-2009-N-0501-0011...
#
# Found 0 comments...
# 2021-05-27 12:06:02: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0011----------------
#
# ******************************
# 2021-05-27 12:06:02: Getting comments for document FDA-2009-N-0501-0012...
#
# 2021-05-27 12:06:02: Getting objectId for document FDA-2009-N-0501-0012...Got it (09000064847f0822)
# 2021-05-27 12:06:02: Getting comment headers associated with document FDA-2009-N-0501-0012...
#
# Found 10 comments...
# 2021-05-27 12:06:03: Inserting 10 records into database...
# 2021-05-27 12:06:03: Writing 10 records to comment_headers_120602.csv...Done
# 2021-05-27 12:06:03: Removing any duplicates in the CSV...
# 2021-05-27 12:06:03: Done. Removed 0 duplicate rows from comment_headers_120602.csv.
# 2021-05-27 12:06:03: Finished: approximately 10 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:06:03: Getting comments associated with document FDA-2009-N-0501-0012...
#
# 2021-05-27 12:06:03: Gathering details for 10 comments...
# 2021-05-27 12:06:05: Inserting 10 records into database...
# 2021-05-27 12:06:05: Finished: 10 comments collected
#
# Done getting all 10 comments for document FDA-2009-N-0501-0012----------------
#
# ******************************
# 2021-05-27 12:06:05: Getting comments for document FDA-2009-N-0501-0005...
#
# 2021-05-27 12:06:05: Getting objectId for document FDA-2009-N-0501-0005...Got it (0900006480aaf366)
# 2021-05-27 12:06:05: Getting comment headers associated with document FDA-2009-N-0501-0005...
#
# Found 0 comments...
# 2021-05-27 12:06:06: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0005----------------
#
# ******************************
# 2021-05-27 12:06:06: Getting comments for document FDA-2009-N-0501-0001...
#
# 2021-05-27 12:06:06: Getting objectId for document FDA-2009-N-0501-0001...Got it (0900006480a4670a)
# 2021-05-27 12:06:06: Getting comment headers associated with document FDA-2009-N-0501-0001...
#
# Found 3 comments...
# 2021-05-27 12:06:07: Inserting 3 records into database...
# 2021-05-27 12:06:07: Writing 3 records to comment_headers_120606.csv...Done
# 2021-05-27 12:06:07: Removing any duplicates in the CSV...
# 2021-05-27 12:06:07: Done. Removed 0 duplicate rows from comment_headers_120606.csv.
# 2021-05-27 12:06:07: Finished: approximately 3 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:06:07: Getting comments associated with document FDA-2009-N-0501-0001...
#
# 2021-05-27 12:06:07: Gathering details for 3 comments...
# 2021-05-27 12:06:08: Inserting 3 records into database...
# 2021-05-27 12:06:08: Finished: 3 comments collected
#
# Done getting all 3 comments for document FDA-2009-N-0501-0001----------------
#
# ******************************
# 2021-05-27 12:06:08: Getting comments for document FDA-2009-N-0501-0008...
#
# 2021-05-27 12:06:08: Getting objectId for document FDA-2009-N-0501-0008...Got it (090000648269fd6f)
# 2021-05-27 12:06:08: Getting comment headers associated with document FDA-2009-N-0501-0008...
#
# Found 0 comments...
# 2021-05-27 12:06:08: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0008----------------
#
# ******************************
# 2021-05-27 12:06:08: Getting comments for document FDA-2009-N-0501-0009...
#
# 2021-05-27 12:06:08: Getting objectId for document FDA-2009-N-0501-0009...Got it (0900006482b6e6bf)
# 2021-05-27 12:06:08: Getting comment headers associated with document FDA-2009-N-0501-0009...
#
# Found 0 comments...
# 2021-05-27 12:06:09: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0009----------------
#
# ******************************
# 2021-05-27 12:06:09: Getting comments for document FDA-2009-N-0501-0006...
#
# 2021-05-27 12:06:09: Getting objectId for document FDA-2009-N-0501-0006...Got it (0900006481725dea)
# 2021-05-27 12:06:09: Getting comment headers associated with document FDA-2009-N-0501-0006...
#
# Found 0 comments...
# 2021-05-27 12:06:09: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0006----------------
#
# ******************************
# 2021-05-27 12:06:09: Getting comments for document FDA-2009-N-0501-0010...
#
# 2021-05-27 12:06:09: Getting objectId for document FDA-2009-N-0501-0010...Got it (0900006482f62fdb)
# 2021-05-27 12:06:10: Getting comment headers associated with document FDA-2009-N-0501-0010...
#
# Found 0 comments...
# 2021-05-27 12:06:10: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0010----------------
#
# ******************************
# 2021-05-27 12:06:10: Getting comments for document FDA-2009-N-0501-0007...
#
# 2021-05-27 12:06:10: Getting objectId for document FDA-2009-N-0501-0007...Got it (0900006481842327)
# 2021-05-27 12:06:10: Getting comment headers associated with document FDA-2009-N-0501-0007...
#
# Found 0 comments...
# 2021-05-27 12:06:11: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0007----------------
#
# DONE retrieving all 13 comments from 9 document(s) for docket FDA-2009-N-0501----------------
#
#
# ********************************
# STARTING EERE-2019-BT-STD-0036
# ********************************
# 2021-05-27 12:06:11: Getting documents associated with docket EERE-2019-BT-STD-0036...
#
# Found 2 documents...
# 2021-05-27 12:06:11: Inserting 2 records into database...
# 2021-05-27 12:06:11: Writing 2 records to document_headers_120611.csv...Done
# 2021-05-27 12:06:11: Removing any duplicates in the CSV...
# 2021-05-27 12:06:11: Done. Removed 0 duplicate rows from document_headers_120611.csv.
# 2021-05-27 12:06:11: Finished: approximately 2 documents collected
#
# Done----------------
#
# ******************************
# 2021-05-27 12:06:11: Getting comments for document EERE-2019-BT-STD-0036-0004...
#
# 2021-05-27 12:06:11: Getting objectId for document EERE-2019-BT-STD-0036-0004...Got it (0900006484aa1342)
# 2021-05-27 12:06:11: Getting comment headers associated with document EERE-2019-BT-STD-0036-0004...
#
# Found 0 comments...
# 2021-05-27 12:06:12: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document EERE-2019-BT-STD-0036-0004----------------
#
# ******************************
# 2021-05-27 12:06:12: Getting comments for document EERE-2019-BT-STD-0036-0001...
#
# 2021-05-27 12:06:12: Getting objectId for document EERE-2019-BT-STD-0036-0001...Got it (0900006484a7a258)
# 2021-05-27 12:06:12: Getting comment headers associated with document EERE-2019-BT-STD-0036-0001...
#
# Found 17 comments...
# 2021-05-27 12:06:13: Inserting 17 records into database...
# 2021-05-27 12:06:13: Writing 17 records to comment_headers_120612.csv...Done
# 2021-05-27 12:06:13: Removing any duplicates in the CSV...
# 2021-05-27 12:06:13: Done. Removed 0 duplicate rows from comment_headers_120612.csv.
# 2021-05-27 12:06:13: Finished: approximately 17 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:06:13: Getting comments associated with document EERE-2019-BT-STD-0036-0001...
#
# 2021-05-27 12:06:13: Gathering details for 17 comments...
# 2021-05-27 12:06:16: Inserting 17 records into database...
# 2021-05-27 12:06:16: Finished: 17 comments collected
#
# Done getting all 17 comments for document EERE-2019-BT-STD-0036-0001----------------
#
# DONE retrieving all 17 comments from 2 document(s) for docket EERE-2019-BT-STD-0036----------------
#
#
# ********************************
# STARTING NHTSA-2019-0121
# ********************************
# 2021-05-27 12:06:16: Getting documents associated with docket NHTSA-2019-0121...
#
# Found 2 documents...
# 2021-05-27 12:06:17: Inserting 2 records into database...
# 2021-05-27 12:06:17: Writing 2 records to document_headers_120617.csv...Done
# 2021-05-27 12:06:17: Removing any duplicates in the CSV...
# 2021-05-27 12:06:17: Done. Removed 0 duplicate rows from document_headers_120617.csv.
# 2021-05-27 12:06:17: Finished: approximately 2 documents collected
#
# Done----------------
#
# ******************************
# 2021-05-27 12:06:17: Getting comments for document NHTSA-2019-0121-0003...
#
# 2021-05-27 12:06:17: Getting objectId for document NHTSA-2019-0121-0003...Got it (090000648428230c)
# 2021-05-27 12:06:17: Getting comment headers associated with document NHTSA-2019-0121-0003...
#
# Found 0 comments...
# 2021-05-27 12:06:18: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document NHTSA-2019-0121-0003----------------
#
# ******************************
# 2021-05-27 12:06:18: Getting comments for document NHTSA-2019-0121-0001...
#
# 2021-05-27 12:06:18: Getting objectId for document NHTSA-2019-0121-0001...Got it (0900006484275b85)
# 2021-05-27 12:06:18: Getting comment headers associated with document NHTSA-2019-0121-0001...
#
# Found 23 comments...
# (Requests left: 600)
# 2021-05-27 12:06:19: Inserting 23 records into database...
# 2021-05-27 12:06:19: Writing 23 records to comment_headers_120618.csv...Done
# 2021-05-27 12:06:19: Removing any duplicates in the CSV...
# 2021-05-27 12:06:19: Done. Removed 0 duplicate rows from comment_headers_120618.csv.
# 2021-05-27 12:06:19: Finished: approximately 23 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:06:19: Getting comments associated with document NHTSA-2019-0121-0001...
#
# 2021-05-27 12:06:19: Gathering details for 23 comments...
# 2021-05-27 12:06:24: Inserting 23 records into database...
# 2021-05-27 12:06:24: Finished: 23 comments collected
#
# Done getting all 23 comments for document NHTSA-2019-0121-0001----------------
#
# DONE retrieving all 23 comments from 2 document(s) for docket NHTSA-2019-0121----------------
#
#
# DONE

# %% [markdown]
# ## Look at the data

# %%
# look at the data

# See readme for database schema. The comment details (including its plain-text) are in comments_detail
import pandas as pd
import sqlite3

conn = sqlite3.connect("my_database2.db")
pd.read_sql_query("select docketId, count(*) as comments from comments_detail group by docketId", conn)
# Out:
#                 docketId  comments
# 0  EERE-2019-BT-STD-0036        17
# 1        FDA-2009-N-0501        13
# 2        NHTSA-2019-0121        23

# %%
conn.close()

# %% [markdown]
# ## Into one CSV per docket
#
# If a path is specified and the directory does not exist, it will be created automatically.

# %%
# alternatively, you could specify the same csv_filename for all iterations and all the data will be appended to a single file
my_dockets = ['FDA-2009-N-0501', 'EERE-2019-BT-STD-0036', 'NHTSA-2019-0121']

for docket_id in my_dockets:
    print(f"\n********************************\nSTARTING {docket_id}\n********************************")
    downloader.gather_comments_by_docket(docket_id, csv_filename=f"mydockets/{docket_id}.csv")

print("\nDONE")
# Out:
# ********************************
# STARTING FDA-2009-N-0501
# ********************************
# 2021-05-27 12:11:53: Getting documents associated with docket FDA-2009-N-0501...
#
# Found 9 documents...
# 2021-05-27 12:11:54: Writing 9 records to document_headers_121153.csv...Done
# 2021-05-27 12:11:54: Removing any duplicates in the CSV...
# 2021-05-27 12:11:54: Done. Removed 0 duplicate rows from document_headers_121153.csv.
# 2021-05-27 12:11:54: Finished: approximately 9 documents collected
#
# Done----------------
#
# ******************************
# 2021-05-27 12:11:54: Getting comments for document FDA-2009-N-0501-0011...
#
# 2021-05-27 12:11:54: Getting objectId for document FDA-2009-N-0501-0011...Got it (09000064845f4f11)
# 2021-05-27 12:11:54: Getting comment headers associated with document FDA-2009-N-0501-0011...
#
# Found 0 comments...
# 2021-05-27 12:11:54: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0011----------------
#
# ******************************
# 2021-05-27 12:11:54: Getting comments for document FDA-2009-N-0501-0012...
#
# 2021-05-27 12:11:54: Getting objectId for document FDA-2009-N-0501-0012...Got it (09000064847f0822)
# 2021-05-27 12:11:55: Getting comment headers associated with document FDA-2009-N-0501-0012...
#
# Found 10 comments...
# 2021-05-27 12:11:56: Writing 10 records to comment_headers_121155.csv...Done
# 2021-05-27 12:11:56: Removing any duplicates in the CSV...
# 2021-05-27 12:11:56: Done. Removed 0 duplicate rows from comment_headers_121155.csv.
# 2021-05-27 12:11:56: Finished: approximately 10 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:11:56: Getting comments associated with document FDA-2009-N-0501-0012...
#
# 2021-05-27 12:11:56: Gathering details for 10 comments...
# 2021-05-27 12:11:58: Writing 10 records to mydockets/FDA-2009-N-0501.csv...Done
# 2021-05-27 12:11:58: Finished: 10 comments collected
#
# Done getting all 10 comments for document FDA-2009-N-0501-0012----------------
#
# ******************************
# 2021-05-27 12:11:58: Getting comments for document FDA-2009-N-0501-0005...
#
# 2021-05-27 12:11:58: Getting objectId for document FDA-2009-N-0501-0005...Got it (0900006480aaf366)
# 2021-05-27 12:11:58: Getting comment headers associated with document FDA-2009-N-0501-0005...
#
# Found 0 comments...
# 2021-05-27 12:11:58: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0005----------------
#
# ******************************
# 2021-05-27 12:11:58: Getting comments for document FDA-2009-N-0501-0001...
#
# 2021-05-27 12:11:58: Getting objectId for document FDA-2009-N-0501-0001...Got it (0900006480a4670a)
# 2021-05-27 12:11:59: Getting comment headers associated with document FDA-2009-N-0501-0001...
#
# Found 3 comments...
# 2021-05-27 12:12:00: Writing 3 records to comment_headers_121159.csv...Done
# 2021-05-27 12:12:00: Removing any duplicates in the CSV...
# 2021-05-27 12:12:00: Done. Removed 0 duplicate rows from comment_headers_121159.csv.
# 2021-05-27 12:12:00: Finished: approximately 3 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:12:00: Getting comments associated with document FDA-2009-N-0501-0001...
#
# 2021-05-27 12:12:00: Gathering details for 3 comments...
# 2021-05-27 12:12:00: Writing 3 records to mydockets/FDA-2009-N-0501.csv...Done
# 2021-05-27 12:12:00: Finished: 3 comments collected
#
# Done getting all 13 comments for document FDA-2009-N-0501-0001----------------
#
# ******************************
# 2021-05-27 12:12:00: Getting comments for document FDA-2009-N-0501-0008...
#
# 2021-05-27 12:12:00: Getting objectId for document FDA-2009-N-0501-0008...Got it (090000648269fd6f)
# 2021-05-27 12:12:00: Getting comment headers associated with document FDA-2009-N-0501-0008...
#
# Found 0 comments...
# 2021-05-27 12:12:01: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0008----------------
#
# ******************************
# 2021-05-27 12:12:01: Getting comments for document FDA-2009-N-0501-0009...
#
# 2021-05-27 12:12:01: Getting objectId for document FDA-2009-N-0501-0009...Got it (0900006482b6e6bf)
# 2021-05-27 12:12:01: Getting comment headers associated with document FDA-2009-N-0501-0009...
#
# Found 0 comments...
# 2021-05-27 12:12:01: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0009----------------
#
# ******************************
# 2021-05-27 12:12:01: Getting comments for document FDA-2009-N-0501-0006...
#
# 2021-05-27 12:12:01: Getting objectId for document FDA-2009-N-0501-0006...Got it (0900006481725dea)
# 2021-05-27 12:12:02: Getting comment headers associated with document FDA-2009-N-0501-0006...
#
# Found 0 comments...
# 2021-05-27 12:12:02: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0006----------------
#
# ******************************
# 2021-05-27 12:12:02: Getting comments for document FDA-2009-N-0501-0010...
#
# 2021-05-27 12:12:02: Getting objectId for document FDA-2009-N-0501-0010...Got it (0900006482f62fdb)
# 2021-05-27 12:12:02: Getting comment headers associated with document FDA-2009-N-0501-0010...
#
# Found 0 comments...
# 2021-05-27 12:12:03: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0010----------------
#
# ******************************
# 2021-05-27 12:12:03: Getting comments for document FDA-2009-N-0501-0007...
#
# 2021-05-27 12:12:03: Getting objectId for document FDA-2009-N-0501-0007...Got it (0900006481842327)
# 2021-05-27 12:12:03: Getting comment headers associated with document FDA-2009-N-0501-0007...
#
# Found 0 comments...
# 2021-05-27 12:12:03: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document FDA-2009-N-0501-0007----------------
#
# DONE retrieving all 13 comments from 9 document(s) for docket FDA-2009-N-0501----------------
#
#
# ********************************
# STARTING EERE-2019-BT-STD-0036
# ********************************
# 2021-05-27 12:12:03: Getting documents associated with docket EERE-2019-BT-STD-0036...
#
# Found 2 documents...
# 2021-05-27 12:12:04: Writing 2 records to document_headers_121203.csv...Done
# 2021-05-27 12:12:04: Removing any duplicates in the CSV...
# 2021-05-27 12:12:04: Done. Removed 0 duplicate rows from document_headers_121203.csv.
# 2021-05-27 12:12:04: Finished: approximately 2 documents collected
#
# Done----------------
#
# ******************************
# 2021-05-27 12:12:04: Getting comments for document EERE-2019-BT-STD-0036-0004...
#
# 2021-05-27 12:12:04: Getting objectId for document EERE-2019-BT-STD-0036-0004...Got it (0900006484aa1342)
# 2021-05-27 12:12:04: Getting comment headers associated with document EERE-2019-BT-STD-0036-0004...
#
# Found 0 comments...
# 2021-05-27 12:12:04: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document EERE-2019-BT-STD-0036-0004----------------
#
# ******************************
# 2021-05-27 12:12:04: Getting comments for document EERE-2019-BT-STD-0036-0001...
#
# 2021-05-27 12:12:04: Getting objectId for document EERE-2019-BT-STD-0036-0001...Got it (0900006484a7a258)
# 2021-05-27 12:12:05: Getting comment headers associated with document EERE-2019-BT-STD-0036-0001...
#
# Found 17 comments...
# 2021-05-27 12:12:06: Writing 17 records to comment_headers_121205.csv...Done
# 2021-05-27 12:12:06: Removing any duplicates in the CSV...
# 2021-05-27 12:12:06: Done. Removed 0 duplicate rows from comment_headers_121205.csv.
# 2021-05-27 12:12:06: Finished: approximately 17 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:12:06: Getting comments associated with document EERE-2019-BT-STD-0036-0001...
#
# 2021-05-27 12:12:06: Gathering details for 17 comments...
# 2021-05-27 12:12:09: Writing 17 records to mydockets/EERE-2019-BT-STD-0036.csv...Done
# 2021-05-27 12:12:09: Finished: 17 comments collected
#
# Done getting all 17 comments for document EERE-2019-BT-STD-0036-0001----------------
#
# DONE retrieving all 17 comments from 2 document(s) for docket EERE-2019-BT-STD-0036----------------
#
#
# ********************************
# STARTING NHTSA-2019-0121
# ********************************
# 2021-05-27 12:12:09: Getting documents associated with docket NHTSA-2019-0121...
#
# Found 2 documents...
# 2021-05-27 12:12:10: Writing 2 records to document_headers_121209.csv...Done
# 2021-05-27 12:12:10: Removing any duplicates in the CSV...
# 2021-05-27 12:12:10: Done. Removed 0 duplicate rows from document_headers_121209.csv.
# 2021-05-27 12:12:10: Finished: approximately 2 documents collected
#
# Done----------------
#
# ******************************
# 2021-05-27 12:12:10: Getting comments for document NHTSA-2019-0121-0003...
#
# 2021-05-27 12:12:10: Getting objectId for document NHTSA-2019-0121-0003...Got it (090000648428230c)
# 2021-05-27 12:12:10: Getting comment headers associated with document NHTSA-2019-0121-0003...
#
# Found 0 comments...
# 2021-05-27 12:12:11: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document NHTSA-2019-0121-0003----------------
#
# ******************************
# 2021-05-27 12:12:11: Getting comments for document NHTSA-2019-0121-0001...
#
# 2021-05-27 12:12:11: Getting objectId for document NHTSA-2019-0121-0001...Got it (0900006484275b85)
# 2021-05-27 12:12:11: Getting comment headers associated with document NHTSA-2019-0121-0001...
#
# Found 23 comments...
# 2021-05-27 12:12:12: Writing 23 records to comment_headers_121211.csv...Done
# 2021-05-27 12:12:12: Removing any duplicates in the CSV...
# 2021-05-27 12:12:12: Done. Removed 0 duplicate rows from comment_headers_121211.csv.
# 2021-05-27 12:12:12: Finished: approximately 23 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:12:12: Getting comments associated with document NHTSA-2019-0121-0001...
#
# 2021-05-27 12:12:12: Gathering details for 23 comments...
# 2021-05-27 12:12:17: Writing 23 records to mydockets/NHTSA-2019-0121.csv...Done
# 2021-05-27 12:12:17: Finished: 23 comments collected
#
# Done getting all 23 comments for document NHTSA-2019-0121-0001----------------
#
# DONE retrieving all 23 comments from 2 document(s) for docket NHTSA-2019-0121----------------
#
#
# DONE

# %% [markdown]
# # Q: How do I download all comments associated with a document?

# %% [markdown]
# ## Into both a database and a CSV
#
# Same idea as above for dockets. Can remove one of the filename parameters to output to only a CSV or a database. If either file exists, the data are appended to the existing database/CSV.

# %%
downloader.gather_comments_by_document("FDA-2009-N-0501-0012", db_filename="mydb3.db", csv_filename="FDA_document.csv")
# Out:
# 2021-05-27 12:18:19: Getting objectId for document FDA-2009-N-0501-0012...Got it (09000064847f0822)
# 2021-05-27 12:18:20: Getting comment headers associated with document FDA-2009-N-0501-0012...
#
# Found 10 comments...
# 2021-05-27 12:18:21: Inserting 10 records into database...
# 2021-05-27 12:18:21: Writing 10 records to comment_headers_121820.csv...Done
# 2021-05-27 12:18:21: Removing any duplicates in the CSV...
# 2021-05-27 12:18:21: Done. Removed 0 duplicate rows from comment_headers_121820.csv.
# 2021-05-27 12:18:21: Finished: approximately 10 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:18:21: Getting comments associated with document FDA-2009-N-0501-0012...
#
# 2021-05-27 12:18:21: Gathering details for 10 comments...
# 2021-05-27 12:18:23: Inserting 10 records into database...
# 2021-05-27 12:18:23: Writing 10 records to FDA_document.csv...Done
# 2021-05-27 12:18:23: Finished: 10 comments collected
#
# Done getting all 10 comments for document FDA-2009-N-0501-0012----------------

# %% [markdown]
# # Q: How do I download all comments associated with *multiple* documents?

# %% [markdown]
# Links to documents used below:
# * https://www.regulations.gov/document/FDA-2009-N-0501-0012
# * https://www.regulations.gov/document/NHTSA-2019-0121-0001
# * https://www.regulations.gov/document/EERE-2019-BT-STD-0036-0001

# %% [markdown]
# ## Into both a database and one CSV per document
#
# Same idea as above for dockets. You can remove one of the filename parameters to output to only a CSV or a database. In addition, you could write all data to a single CSV instead of one per document.

# %%
my_documents = ['FDA-2009-N-0501-0012', 'NHTSA-2019-0121-0001', 'EERE-2019-BT-STD-0036-0001']

for document_id in my_documents:
    print(f"\n********************************\nSTARTING {document_id}\n********************************")
    downloader.gather_comments_by_document(document_id, db_filename="mydb.db", csv_filename=f"mydocuments/{document_id}.csv")

print("\nDONE")
# Out:
# ********************************
# STARTING FDA-2009-N-0501-0012
# ********************************
# 2021-05-27 12:20:40: Getting objectId for document FDA-2009-N-0501-0012...Got it (09000064847f0822)
# 2021-05-27 12:20:40: Getting comment headers associated with document FDA-2009-N-0501-0012...
#
# Found 10 comments...
# 2021-05-27 12:20:41: Inserting 10 records into database...
# 2021-05-27 12:20:41: Writing 10 records to comment_headers_122040.csv...Done
# 2021-05-27 12:20:41: Removing any duplicates in the CSV...
# 2021-05-27 12:20:41: Done. Removed 0 duplicate rows from comment_headers_122040.csv.
# 2021-05-27 12:20:41: Finished: approximately 10 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:20:41: Getting comments associated with document FDA-2009-N-0501-0012...
#
# 2021-05-27 12:20:41: Gathering details for 10 comments...
# 2021-05-27 12:20:43: Inserting 10 records into database...
# 2021-05-27 12:20:43: Writing 10 records to mydocuments/FDA-2009-N-0501-0012.csv...Done
# 2021-05-27 12:20:43: Finished: 10 comments collected
#
# Done getting all 10 comments for document FDA-2009-N-0501-0012----------------
#
#
# ********************************
# STARTING NHTSA-2019-0121-0001
# ********************************
# 2021-05-27 12:20:43: Getting objectId for document NHTSA-2019-0121-0001...Got it (0900006484275b85)
# 2021-05-27 12:20:43: Getting comment headers associated with document NHTSA-2019-0121-0001...
#
# Found 23 comments...
# 2021-05-27 12:20:44: Inserting 23 records into database...
# 2021-05-27 12:20:44: Writing 23 records to comment_headers_122043.csv...Done
# 2021-05-27 12:20:44: Removing any duplicates in the CSV...
# 2021-05-27 12:20:44: Done. Removed 0 duplicate rows from comment_headers_122043.csv.
# 2021-05-27 12:20:44: Finished: approximately 23 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:20:44: Getting comments associated with document NHTSA-2019-0121-0001...
#
# 2021-05-27 12:20:44: Gathering details for 23 comments...
# 2021-05-27 12:20:49: Inserting 23 records into database...
# 2021-05-27 12:20:49: Writing 23 records to mydocuments/NHTSA-2019-0121-0001.csv...Done
# 2021-05-27 12:20:49: Finished: 23 comments collected
#
# Done getting all 23 comments for document NHTSA-2019-0121-0001----------------
#
#
# ********************************
# STARTING EERE-2019-BT-STD-0036-0001
# ********************************
# 2021-05-27 12:20:49: Getting objectId for document EERE-2019-BT-STD-0036-0001...Got it (0900006484a7a258)
# 2021-05-27 12:20:49: Getting comment headers associated with document EERE-2019-BT-STD-0036-0001...
#
# Found 17 comments...
# 2021-05-27 12:20:50: Inserting 17 records into database...
# 2021-05-27 12:20:50: Writing 17 records to comment_headers_122049.csv...Done
# 2021-05-27 12:20:50: Removing any duplicates in the CSV...
# 2021-05-27 12:20:50: Done. Removed 0 duplicate rows from comment_headers_122049.csv.
# 2021-05-27 12:20:50: Finished: approximately 17 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 12:20:50: Getting comments associated with document EERE-2019-BT-STD-0036-0001...
#
# 2021-05-27 12:20:50: Gathering details for 17 comments...
# 2021-05-27 12:20:53: Inserting 17 records into database...
# 2021-05-27 12:20:53: Writing 17 records to mydocuments/EERE-2019-BT-STD-0036-0001.csv...Done
# 2021-05-27 12:20:54: Finished: 17 comments collected
#
# Done getting all 17 comments for document EERE-2019-BT-STD-0036-0001----------------
#
#
# DONE

# %% [markdown]
# ## Look at the data

# %%
# look at the data

# See readme for database schema. The comment details (including its plain-text) are in comments_detail
import pandas as pd
import sqlite3

conn = sqlite3.connect("mydb.db")
pd.read_sql_query("select commentOnDocumentId, count(*) as comments from comments_detail group by commentOnDocumentId", conn)
# Out:
#           commentOnDocumentId  comments
# 0  EERE-2019-BT-STD-0036-0001        17
# 1        FDA-2009-N-0501-0012        10
# 2        NHTSA-2019-0121-0001        23

# %%
conn.close()

# %% [markdown]
# # Q: How do I find out the number of [dockets/documents/comments] that would be returned by a query using some parameters?
#
# Parameters need to be specified in accordance with the Regulations.gov API. See: https://open.gsa.gov/api/regulationsgov/#api-calls
#
# Note about date formats: postedDate uses yyyy-mm-dd, while lastModifiedDate uses yyyy-mm-dd hh24:mi:ss (Eastern time zone)

# %%
# Get the number of comments associated with EPA dockets posted between 1/1/2021 and 1/7/2021
downloader.get_items_count("comments", params={'filter[postedDate][ge]': '2021-01-01',
                                               'filter[postedDate][le]': '2021-01-07',
                                               'filter[agencyId]': 'EPA'})
# Out:
# 290

# %% [markdown]
# # Q: How do I download all [dockets/documents/comments] associated with some parameters?

# %% [markdown]
# ## 1. Get the header information

# %%
params = {'filter[postedDate][ge]': '2021-01-01',
          'filter[postedDate][le]': '2021-01-07',
          'filter[agencyId]': 'EPA'}

downloader.gather_headers("comments", params, csv_filename="EPA_January_2021Week1_headers.csv")
# Out:
# Found 290 comments...
#
# Enter outer loop (0 comments collected)...
#     250 comments retrieved
#     290 comments retrieved
# 2021-05-27 12:27:24: Writing 290 records to EPA_January_2021Week1.csv...Done
# 2021-05-27 12:27:24: Removing any duplicates in the CSV...
# 2021-05-27 12:27:24: Done. Removed 0 duplicate rows from EPA_January_2021Week1.csv.
# 2021-05-27 12:27:24: Finished: approximately 290 comments collected

# %% [markdown]
# ## 2. Get the IDs associated with those headers

# %%
comment_ids = downloader.get_ids_from_csv("EPA_January_2021Week1_headers.csv", data_type="comments")
len(comment_ids)
# Out:
# 290

# %% [markdown]
# ## 3. Get the detail information
#
# This is slower than the above because it gets each comment one at a time. You are more likely to hit your request limit (1000 requests/hr) in this step.
#
# Data is written out to a file every 500 rows by default, but this can be customized via the insert_every_n_rows parameter

# %%
downloader.gather_details("comments", comment_ids, csv_filename="EPA_January_2021Week1.csv")
# Out:
# 2021-05-27 12:29:11: Gathering details for 290 comments...
# (Requests left: 300)
# (Requests left: 200)
# 2021-05-27 12:30:10: Writing 290 records to EPA_January_2021Week1.csv...Done
# 2021-05-27 12:30:10: Finished: 290 comments collected
