# %%
import pandas as pd
import sqlite3
import getpass
from comments_downloader import CommentsDownloader

# %%
api_key = getpass.getpass("Enter API key")
downloader = CommentsDownloader(api_key)
downloader.get_requests_remaining()
# Out:
# 768

# %% [markdown]
# # Test get_request_json

# %%
# test dockets header response
downloader.get_request_json(f'https://api.regulations.gov/v4/dockets',
                         params={"filter[agencyId]": "EPA",
                                 "filter[lastModifiedDate][ge]": "2021-01-01 00:00:00",
                                 "filter[lastModifiedDate][le]": "2021-01-05 23:59:59",})
# Out:
# {'data': [{'id': 'EPA-HQ-OPP-2016-0140',
#    'type': 'dockets',
#    'attributes': {'docketType': 'Nonrulemaking',
#     'lastModifiedDate': '2021-01-05T08:37:37Z',
#     'highlightedContent': None,
#     'agencyId': 'EPA',
#     'title': 'Pesticide Registration  Review for Zinc Phosphide',
#     'objectId': '0b00006481e9d9e4'},
#    'links': {'self': 'https://api.regulations.gov/v4/dockets/EPA-HQ-OPP-2016-0140'}},
#   {'id': 'EPA-HQ-OPPT-2019-0501',
#    'type': 'dockets',
#    'attributes': {'docketType': 'Nonrulemaking',
#     'lastModifiedDate': '2021-01-04T09:03:58Z',
#     'highlightedContent': None,
#     'agencyId': 'EPA',
#     'title': 'Toxic Substances Control Act (TSCA) Science Advisory Committee on Chemicals Review of Risk Evaluation for Asbestos',
#     'objectId': '0b00006483e58844'},
#    'links': {'self': 'https://api.regulations.gov/v4/dockets/EPA-HQ-OPPT-2019-0501'}},
#   {'id': 'EPA-HQ-OPP-2020-0384',
#    'type': 'dockets',
#    'attributes': {'docketType': 'Nonrulemaking',
#     'lastModifiedDate': '2021-01-05T08:37:48Z',
#     'highlightedContent': None,
#     'agencyId': 'EPA',
#     'title': 'Aminocyclopyrachlor Registration Review',
#     'objectId': '0b00006484795ac8'},
#    'links': {'self': 'https://api.regulations.gov/v4/dockets/EPA-HQ-OPP-2020-0384'}},
#   {'id': 'EPA-R09-OAR-2019-0471',
#    'type': 'dockets',
#    'attributes': {'docketType': 'Nonrulemaking',
#     'lastModifiedDate': '2021-01-05T14:47:24Z',
#     'highlightedContent': None,
#     'agencyId': 'EPA',
#     'title': 'Navajo Nation: Supplemental Title V Delegation Agreement and Treatment as State - Former Bennett Freeze Area',
#     'objectId': '0b00006483de069c'},
#    'links': {'self': 'https://api.regulations.gov/v4/dockets/EPA-R09-OAR-2019-0471'}},
#   {'id': 'EPA-HQ-OGC-2020-0569',
#    'type': 'dockets',
#    'attributes': {'docketType': 'Nonrulemaking',
#     'lastModifiedDate': '2021-01-05T17:49:18Z',
#     'highlightedContent': None,
#     'agencyId': 'EPA',
#     'title': 'Sierra Club v. Wheeler, No. 2:20-cv-00725-SMB (D. AZ)',
#     'objectId': '0b0000648494205c'},
#    'links': {'self': 'https://api.regulations.gov/v4/dockets/EPA-HQ-OGC-2020-0569'}},
#   {'id': 'EPA-HQ-OPP-2013-0368',
#    'type': 'dockets',
#    'attributes': {'docketType': 'Nonrulemaking',
#     'lastModifiedDate': '2021-01-04T13:18:26Z',
#     'highlightedContent': None,
#     'agencyId': 'EPA',
#     'title': 'Pymetrozine Registration Review',
#     'objectId': '0b000064812ae12d'},
#    'links': {'self': 'https://api.regulations.gov/v4/dockets/EPA-HQ-OPP-2013-0368'}},
#   {'id': 'EPA-R08-OAR-2021-0012',
#    'type': 'dockets',
#    'attributes': {'docketType': 'Nonrulemaking',
#     'lastModifiedDate': '2021-01-05T12:24:36Z',
#     'highlightedContent': None,
#     'agencyId': 'EPA',
#     'title': 'WPX Energy Williston, LLC - Ruby 31-30H Pad, Part 71 Initial Permit',
#     'objectId': '0b000064849df182'},
#    'links': {'self': 'https://api.regulations.gov/v4/dockets/EPA-R08-OAR-2021-0012'}},
#   {'id': 'EPA-HQ-OLEM-2020-0462',
#    'type': 'dockets',
#    'attributes': {'docketType': 'Nonrulemaking',
#     'lastModifiedDate': '2021-01-05T17:48:14Z',
#     'highlightedContent': None,
#     'agencyId': 'EPA',
#     'title': 'Draft National Recycling Strategy',
#     'objectId': '0b00006484826196'},
#    'links': {'self': 'https://api.regulations.gov/v4/dockets/EPA-HQ-OLEM-2020-0462'}},
#   {'id': 'EPA-HQ-OPP-2020-0570',
#    'type': 'dockets',
#    'attributes': {'docketType': 'Nonrulemaking',
#     'lastModifiedDate': '2021-01-05T08:37:59Z',
#     'highlightedContent': None,
#     'agencyId': 'EPA',
#     'title': 'Broflanilide; Receipt of Application for Emergency Exemption, Solicitation of Public Comment',
#     'objectId': '0b00006484941e69'},
#    'links': {'self': 'https://api.regulations.gov/v4/dockets/EPA-HQ-OPP-2020-0570'}},
#   {'id': 'EPA-HQ-OPP-2019-0524',
#    'type': 'dockets',
#    'attributes': {'docketType': 'Nonrulemaking',
#     'lastModifiedDate': '2021-01-05T11:29:10Z',
#     'highlightedContent': None,
#     'agencyId': 'EPA',
#     'title': 'Saflufenacil Registration Review Docket',
#     'objectId': '0b00006483ed02c4'},
#    'links': {'self': 'https://api.regulations.gov/v4/dockets/EPA-HQ-OPP-2019-0524'}}],
#  'meta': {'aggregations': {'priorityCategory': [],
#    'docketType': [{'docCount': 10, 'label': 'Nonrulemaking'}],
#    'major': [],
#    'ruleStage': [],
#    'smallEntities': [],
#    'energyAffected': [],
#    'eo13771Designation': [],
#    'agencyId': [{'docCount': 22, 'value': 'FDA'},
#     {'docCount': 18, 'value': 'FAA'},
#     {'docCount': 10, 'value': 'EPA'},
#     {'docCount': 6, 'value': 'NHTSA'},
#     {'docCount': 5, 'value': 'USCG'},
#     {'docCount': 4, 'value': 'PHMSA'},
#     {'docCount': 3, 'value': 'CMS'},
#     {'docCount': 3, 'value': 'FMCSA'},
#     {'docCount': 3, 'value': 'FWS'},
#     {'docCount': 3, 'value': 'NRC'},
#     {'docCount': 3, 'value': 'USCIS'},
#     {'docCount': 2, 'value': 'APHIS'},
#     {'docCount': 2, 'value': 'CPSC'},
#     {'docCount': 2, 'value': 'DEA'},
#     {'docCount': 2, 'value': 'DHS'},
#     {'docCount': 2, 'value': 'EERE'},
#     {'docCount': 2, 'value': 'FRA'},
#     {'docCount': 2, 'value': 'NOAA'},
#     {'docCount': 2, 'value': 'TTB'},
#     {'docCount': 1, 'value': 'AMS'},
#     {'docCount': 1, 'value': 'ATBCB'},
#     {'docCount': 1, 'value': 'BOEM'},
#     {'docCount': 1, 'value': 'CDC'},
#     {'docCount': 1, 'value': 'DOT'},
#     {'docCount': 1, 'value': 'ED'},
#     {'docCount': 1, 'value': 'EOIR'},
#     {'docCount': 1, 'value': 'FEMA'},
#     {'docCount': 1, 'value': 'FHWA'},
#     {'docCount': 1, 'value': 'FNS'},
#     {'docCount': 1, 'value': 'FTA'},
#     {'docCount': 1, 'value': 'HHS'},
#     {'docCount': 1, 'value': 'NCUA'},
#     {'docCount': 1, 'value': 'NIST'},
#     {'docCount': 1, 'value': 'NLRB'},
#     {'docCount': 1, 'value': 'NTSB'},
#     {'docCount': 1, 'value': 'OSHA'},
#     {'docCount': 1, 'value': 'OSM'},
#     {'docCount': 1, 'value': 'PTO'},
#     {'docCount': 1, 'value': 'SSA'},
#     {'docCount': 1, 'value': 'USCBP'}],
#    'internationalInterest': []},
#   'filters': {'lastModifiedDate': {'fromDate': '2021-01-01 00:00:00',
#     'toDate': '2021-01-05 23:59:59'},
#    'agencyId': [{'label': 'EPA', 'value': 'EPA'}]},
#   'hasNextPage': False,
#   'hasPreviousPage': False,
#   'numberOfElements': 10,
#   'pageNumber': 1,
#   'pageSize': 250,
#   'totalElements': 10,
#   'totalPages': 1,
#   'lastPage': True,
#   'firstPage': True}}

# %%
# test documents header response
downloader.get_request_json(f'https://api.regulations.gov/v4/documents',
                         params={"filter[agencyId]": "EPA",
                                 "filter[lastModifiedDate][ge]": "2021-01-01 00:00:00",
                                 "filter[lastModifiedDate][le]": "2021-01-05 23:59:59",})
# Out:
# {'data': [{'id': 'EPA-HQ-OPP-2008-0331-0178',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-04T12:06:24Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Considerations for Bridging Bee-Related Effects and Exposure Data\nfor the Pyrethroids and Pyrethrins',
#     'postedDate': '2021-01-04T05:00:00Z',
#     'docketId': 'EPA-HQ-OPP-2008-0331',
#     'subtype': 'Risk Assessment',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849a28a2'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPP-2008-0331-0178'}},
#   {'id': 'EPA-HQ-OAR-2002-0055-0007',
#    'type': 'documents',
#    'attributes': {'documentType': 'Rule',
#     'lastModifiedDate': '2021-01-04T21:50:27Z',
#     'highlightedContent': '',
#     'frDocNum': '26690',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'National Emission Standards for Hazardous Air Pollutants for Brick and Structural Clay Products Manufacturing; and National Emission Standards for Hazardous Air Pollutants for Clay Ceramics Manufacturing; Final Rule',
#     'postedDate': None,
#     'docketId': 'EPA-HQ-OAR-2002-0055',
#     'subtype': 'Final Rule',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800be9ee'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0055-0007'}},
#   {'id': 'EPA-HQ-OAR-2002-0055-0012',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-04T22:28:46Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Howard Peller, Fioriware from Richard J. Marinshaw, USEPA re: sending a copy of cover letter regarding ICR forms [A-2000-48-II-C-60]',
#     'postedDate': '2002-06-19T04:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0055',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bea36'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0055-0012'}},
#   {'id': 'EPA-HQ-OPP-2010-0686-0008',
#    'type': 'documents',
#    'attributes': {'documentType': 'Notice',
#     'lastModifiedDate': '2021-01-04T02:00:56Z',
#     'highlightedContent': '',
#     'frDocNum': '2020-24524',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': '2021-01-05T04:59:59Z',
#     'title': 'Pesticide Registration Review: Draft Human Health and/or Ecological Risk Assessments for Several Pesticides',
#     'postedDate': '2020-11-05T05:00:00Z',
#     'docketId': 'EPA-HQ-OPP-2010-0686',
#     'subtype': None,
#     'commentStartDate': '2020-11-05T05:00:00Z',
#     'openForComment': False,
#     'objectId': '090000648494d1ae'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPP-2010-0686-0008'}},
#   {'id': 'EPA-HQ-OLEM-2020-0354-0001',
#    'type': 'documents',
#    'attributes': {'documentType': 'Notice',
#     'lastModifiedDate': '2021-01-04T02:03:22Z',
#     'highlightedContent': '',
#     'frDocNum': '2020-24543',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': '2021-01-05T04:59:59Z',
#     'title': 'Agency Information Collection Activities; Proposals, Submissions, and Approvals: Results of Newly Required Annual and Triennial Testing to Evaluate the Impacts of 2015 Federal Underground Storage Tank Regulation',
#     'postedDate': '2020-11-05T05:00:00Z',
#     'docketId': 'EPA-HQ-OLEM-2020-0354',
#     'subtype': 'Information Collection Request (ICR)',
#     'commentStartDate': '2020-11-05T05:00:00Z',
#     'openForComment': False,
#     'objectId': '090000648494c76d'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OLEM-2020-0354-0001'}},
#   {'id': 'EPA-HQ-OPP-2013-0779-0019',
#    'type': 'documents',
#    'attributes': {'documentType': 'Notice',
#     'lastModifiedDate': '2021-01-05T02:03:57Z',
#     'highlightedContent': '',
#     'frDocNum': '2020-24524',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': '2021-01-05T04:59:59Z',
#     'title': 'Pesticide Registration Review: Draft Human Health and/or Ecological Risk Assessments for Several Pesticides',
#     'postedDate': '2020-11-05T05:00:00Z',
#     'docketId': 'EPA-HQ-OPP-2013-0779',
#     'subtype': None,
#     'commentStartDate': '2020-11-05T05:00:00Z',
#     'openForComment': False,
#     'objectId': '090000648494cee7'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPP-2013-0779-0019'}},
#   {'id': 'EPA-HQ-OPP-2015-0288-0038',
#    'type': 'documents',
#    'attributes': {'documentType': 'Notice',
#     'lastModifiedDate': '2021-01-05T02:01:07Z',
#     'highlightedContent': '',
#     'frDocNum': '2020-24524',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': '2021-01-05T04:59:59Z',
#     'title': 'Pesticide Registration Review: Draft Human Health and/or Ecological Risk Assessments for Several Pesticides',
#     'postedDate': '2020-11-05T05:00:00Z',
#     'docketId': 'EPA-HQ-OPP-2015-0288',
#     'subtype': None,
#     'commentStartDate': '2020-11-05T05:00:00Z',
#     'openForComment': False,
#     'objectId': '090000648494d1ac'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPP-2015-0288-0038'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0049',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T17:03:06Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Recommendation for emission testing at North American Refractories Company, Womelsdorf, Pennsylvania MACT Analysis for the Chromium Refractories Manufacturing Industry NESHAP, Midwest Research Institute (MRI) [A-2000-50-II-B-017]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Public Comment',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800badfa'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0049'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0046',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T16:56:02Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Plant location and estimated emissions for risk modeling Maximum Achievable Control Technology (MACT) Standard support; information analysis for the chromium Refractories Manufacturing Industry, Midwest Research Institute, USEPA [A-2000-0050-II-B-014]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Public Comment',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800badec'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0046'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0125',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:01:35Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Unifrax Corporation from Richard Marinshaw, Midwest Research Institute (MRI) re: an error in the information collection request (ICR) sent to them by the USEPA [A-2000-50-II-C-50]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baf53'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0125'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0128',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:03:54Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Susan P. Zapata, USEPA from James Benson, Vice President of Manufacturing and Technology, Refractory Technology Inc. re: Refractories Manufacturing maximum achievable control technology (MACT) information collection request (ICR) [A-2000-50-II-C-53]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baf64'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0128'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0130',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:06:00Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Susan Zapata, OAQPS/USEPA from William Carmean, Allied Mineral Products, Inc. re: an extension request on information collection request (ICR) for refractories manufacturing operations [A-2000-50-II-C-55]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baf6b'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0130'}},
#   {'id': 'EPA-R01-OAR-2019-0695-0028',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:08:01Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': "Appropriation for Department of Environmental Protection _ Governor's FY21 Budget Recommendation",
#     'postedDate': '2021-01-05T05:00:00Z',
#     'docketId': 'EPA-R01-OAR-2019-0695',
#     'subtype': None,
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '090000648498ddcb'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-R01-OAR-2019-0695-0028'}},
#   {'id': 'EPA-HQ-OPPT-2019-0501-0141',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T01:47:07Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'How to Change Drum Brakes O’Reilly Auto Parts',
#     'postedDate': '2021-01-04T05:00:00Z',
#     'docketId': 'EPA-HQ-OPPT-2019-0501',
#     'subtype': None,
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849ce1d3'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPPT-2019-0501-0141'}},
#   {'id': 'EPA-HQ-OGC-2020-0717-0002',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T01:36:18Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Env Defense-#950285-v1-WY Regional Haze PacifCorp Wyodak Settlement Signed Pre 113g',
#     'postedDate': '2021-01-04T05:00:00Z',
#     'docketId': 'EPA-HQ-OGC-2020-0717',
#     'subtype': 'Agreement, Contract',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849d2d6c'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OGC-2020-0717-0002'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0423',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T18:19:40Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'BMI France Snow Shoe Plant; Section 3 (continued)  Material Safety Data Sheets Products and Additives and Section 4 Title V Permit Application [A-2000-50-II-D-213]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Public Comment',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bb6c8'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0423'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0426',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T18:11:22Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Final report entitled American Premier, Inc. Refractories Manufacturing MACT Questionnaire: Maple Grove, Ohio Facility [A-2000-50-II-D-221]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Public Comment',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bb720'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0426'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0409',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T18:47:57Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to  Bruce Jordan, USEPA and Susan Zapata, USEPA from David E. Haney, Manager, Environmental, Health, and Safety, BMI France; re: response to Section 114 information collection request for facilities in Altoona, PA; Canon City, CO; Crown Point, IN [A-2000-50-II-D-213]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Public Comment',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bb5c7'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0409'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0345',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T18:56:30Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'J. Ingram, Vesuvius USA, to S. Zapata, EPA:ESD. Request for extension until February 20,1998 for submission of response to Section 114 information collection request [A-2000-50-II-D-150]',
#     'postedDate': '2004-07-26T04:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Public Comment',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bb41a'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0345'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0422',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T18:13:15Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': "Documents concerning BMI France's Snow Shoe, PA plant [A-2000-50-II-D-213]",
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Public Comment',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bb6af'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0422'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0020',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T19:48:31Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'American Society of Mechanical Engineers, ASME PTC 19-10-1981-Part 10, Flue and Exhausts Gas Analyses, New York, NY [A-2000-50-IV-J-01]',
#     'postedDate': None,
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Other',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bad51'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0020'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0023',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T19:56:07Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Miller, B., Redland Brick, Inc., to Air and Radiation Docket and Information Center (6102), U.S. Environmental Protection Agency. September 11, 2002. Comments on the proposed  Brick and Structural Clay Products NESHAP [A-2000-50-IV-J-04]',
#     'postedDate': None,
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Other',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bad63'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0023'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0003',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T19:00:44Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Economic Impact Analysis of the Refractory Product Manufacturing NESHAP - Final Rule. EPA 452/R-03-004 [A-2000-50-IV-A-01]',
#     'postedDate': None,
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Publication',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bacf2'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0003'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0009',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T19:10:15Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Marinshaw, R., J. Fields, RTI, to Fairchild, S., EPA/ESD. Revised Estimated Compliance Costs for the Refractory Products Manufacturing Industry  [A-2000-50-IV-B-06]',
#     'postedDate': None,
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bad15'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0009'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0088',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:19:36Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Correspondence to Greg Daum, Zedmark from Janet Marron, Environmental Scientist, Midwest Research Institute re: Maximum Achievable Control Technology (MACT) Standard Support: Information Analysis for the Chromium Refractories Manufacturing Industry [A-2000-50-II-C-13]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baea9'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0088'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0054',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T00:31:55Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Memorandum to EPA Regional Offices from John Seitz, Director Office of Air Quality Planning and Standards (MD-10) [A-2000-50-II-B-022]',
#     'postedDate': '2002-08-02T04:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bae10'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0054'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0062',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T00:44:35Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Memorandum to Susan Zapata EPA/ESD/MICG (MD-13) USEPA from Richard Marinshaw, Midwest Research Institute (MR) about the Revised Refractory Thermal Processing Model [A-2000-50-II-B-031]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bae35'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0062'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0066',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T00:51:01Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Trip Report: Premier Refractories, Snow Shoe, Pennsylvania on March 7, 1999 [A-2000-50-II-B-035]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Report',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bae46'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0066'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0073',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T00:57:41Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Susan Zapata EPA/ESD/MICG from Richard Marinshaw and Jennifer Fields, Midwest Research Institute re: Recommended Control Efficiencies for Estimating Baseline Hazardous Air Pollutants (HAP) Emissions and Emission Reductions [A-2000-50-II-B-042]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bae60'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0073'}},
#   {'id': 'EPA-R01-UST-2020-0207-0002',
#    'type': 'documents',
#    'attributes': {'documentType': 'Rule',
#     'lastModifiedDate': '2021-01-06T02:01:47Z',
#     'highlightedContent': '',
#     'frDocNum': '2020-25831',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': '2021-01-12T04:59:59Z',
#     'title': 'Final Approval of State Underground Storage Tank Program Revisions, Codification and Incorporation by Reference: Rhode Island',
#     'postedDate': '2020-12-11T05:00:00Z',
#     'docketId': 'EPA-R01-UST-2020-0207',
#     'subtype': None,
#     'commentStartDate': '2020-12-11T05:00:00Z',
#     'openForComment': False,
#     'objectId': '0900006484998046'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-R01-UST-2020-0207-0002'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0126',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:02:19Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to American Premier Incorporated from Richard Marinshaw, Midwest Research Institute (MRI) re: an update to an information collection request (ICR) [A-2000-50-II-C-51]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baf59'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0126'}},
#   {'id': 'EPA-HQ-OPP-2015-0474-0041',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:48:55Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Data Evaluation Report on the Acute Toxicity of Prothioconazole-S-methyl to Americamysis bahia',
#     'postedDate': '2021-01-05T05:00:00Z',
#     'docketId': 'EPA-HQ-OPP-2015-0474',
#     'subtype': 'Report',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '090000648497183e'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPP-2015-0474-0041'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0109',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:42:15Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Correspondence to Charles Marvin, The Refractories Institute from Evalyn Gonzales, Midwest Research Institute re: refractory manufacturers list [A-2000-50-II-C-34]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baf0c'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0109'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0156',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:30:16Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Correspondence to Steve Cox, Technical Manager, North American Refractories Company (NARCO), from Richard Marinshaw, Midwest Research Company (MRI), re: request for pictures for draft report [A-2000-50-II-C-81]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bafd8'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0156'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0160',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:35:57Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Michael Higgs, SGL Carbon Corporation from James Crowder, USEPA re: National emission standard for hazardous air pollutants [A-2000-50-II-C-85]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bafe8'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0160'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0157',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:31:30Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Charles Marvin Executive Vice President, The Refractories Institute, from Richard Marinshaw, Midwest Research Institute (MRI) [A-2000-50-II-C-82]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bafdc'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0157'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0153',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:28:08Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Chester Zalewski, Harbison Walker Refractories Company, from James Crowder, Group Leader, USEPA, re: request a visit to facility for the development of national emission standard for hazardous air pollutants (NESHAP) [A-2000-50-II-C-78]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bafcb'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0153'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0140',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:16:30Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'W. Lamason, EPA:ESD, to K. Nelson, North American Refractories Company. Transmitting supplemental data requested by Mr. Nelson in his September 17, 1997 letter for the emission test at the Womelsdorf, Pennsylvania, facility [A-2000-50-II-C-65]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baf95'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0140'}},
#   {'id': 'EPA-HQ-OAR-2018-0279-0585',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T01:35:31Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'OMB email 12 21 2020',
#     'postedDate': '2021-01-04T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2018-0279',
#     'subtype': 'Interagency Review',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849c4f74'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2018-0279-0585'}},
#   {'id': 'EPA-HQ-OPP-2013-0374-0030',
#    'type': 'documents',
#    'attributes': {'documentType': 'Notice',
#     'lastModifiedDate': '2021-01-05T02:01:38Z',
#     'highlightedContent': '',
#     'frDocNum': '2020-24524',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': '2021-01-05T04:59:59Z',
#     'title': 'Pesticide Registration Review: Draft Human Health and/or Ecological Risk Assessments for Several Pesticides',
#     'postedDate': '2020-11-05T05:00:00Z',
#     'docketId': 'EPA-HQ-OPP-2013-0374',
#     'subtype': None,
#     'commentStartDate': '2020-11-05T05:00:00Z',
#     'openForComment': False,
#     'objectId': '090000648494ceeb'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPP-2013-0374-0030'}},
#   {'id': 'EPA-HQ-OPPT-2019-0501-0121',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T01:42:29Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': '5 - Asbestos Part 1 SR Supplemental File Data Quality Evaluation of Environmental Releases and Occupational Exposure',
#     'postedDate': '2021-01-04T05:00:00Z',
#     'docketId': 'EPA-HQ-OPPT-2019-0501',
#     'subtype': 'Evaluation',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849c2671'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPPT-2019-0501-0121'}},
#   {'id': 'EPA-HQ-OPPT-2019-0501-0132',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T01:43:28Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Nontechnical Summary of the Risk Evaluation for Asbestos Part 1',
#     'postedDate': '2021-01-04T05:00:00Z',
#     'docketId': 'EPA-HQ-OPPT-2019-0501',
#     'subtype': 'Evaluation',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849c29d0'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPPT-2019-0501-0132'}},
#   {'id': 'EPA-HQ-OPPT-2019-0501-0147',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T01:45:39Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Washington Better Brakes Law Chapter 173-901 WAC',
#     'postedDate': '2021-01-04T05:00:00Z',
#     'docketId': 'EPA-HQ-OPPT-2019-0501',
#     'subtype': None,
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849ce1d9'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPPT-2019-0501-0147'}},
#   {'id': 'EPA-HQ-OPPT-2019-0501-0125',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T01:51:30Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': '9 - Asbestos Part 1 SR Supplemental File Data Quality Evaluation of Ecological Hazard Studies',
#     'postedDate': '2021-01-04T05:00:00Z',
#     'docketId': 'EPA-HQ-OPPT-2019-0501',
#     'subtype': 'Evaluation',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849c29c9'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPPT-2019-0501-0125'}},
#   {'id': 'EPA-HQ-OPPT-2019-0501-0140',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T01:47:32Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'How to Change Drum Brakes Autozone',
#     'postedDate': '2021-01-04T05:00:00Z',
#     'docketId': 'EPA-HQ-OPPT-2019-0501',
#     'subtype': None,
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849ce1d2'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPPT-2019-0501-0140'}},
#   {'id': 'EPA-HQ-OPPT-2019-0501-0143',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T01:46:26Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Internet search results for how to replace drum brakes',
#     'postedDate': '2021-01-04T05:00:00Z',
#     'docketId': 'EPA-HQ-OPPT-2019-0501',
#     'subtype': None,
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849ce1d5'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPPT-2019-0501-0143'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0048',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T23:36:17Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Susan Fairchild-Zapata, USEPA, from Janet Marron and Richard Marinshaw, Midwest Research Institute (MRI), re:  Site visit: North American Refractories Company, Womelsdorf, Pennyslvania [A-2000-50 II-B-016]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800badf4'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0048'}},
#   {'id': 'EPA-R09-OAR-2020-0534-0027',
#    'type': 'documents',
#    'attributes': {'documentType': 'Proposed Rule',
#     'lastModifiedDate': '2021-01-04T02:03:56Z',
#     'highlightedContent': '',
#     'frDocNum': '2020-26648',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': '2021-01-05T04:59:59Z',
#     'title': 'Air Quality State Implementation Plans; Approvals and Promulgations: California; Plumas County; Moderate Area Plan for the 2012 Fine Particulate Matter  National Ambient Air Quality Standard',
#     'postedDate': '2020-12-03T05:00:00Z',
#     'docketId': 'EPA-R09-OAR-2020-0534',
#     'subtype': None,
#     'commentStartDate': '2020-12-03T05:00:00Z',
#     'openForComment': False,
#     'objectId': '090000648498409d'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-R09-OAR-2020-0534-0027'}},
#   {'id': 'EPA-HQ-OPP-2015-0736-0009',
#    'type': 'documents',
#    'attributes': {'documentType': 'Other',
#     'lastModifiedDate': '2021-01-04T07:00:41Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Comment Period Extension  for Isothiazolinones Draft Risk Assessment',
#     'postedDate': '2020-06-08T04:00:00Z',
#     'docketId': 'EPA-HQ-OPP-2015-0736',
#     'subtype': None,
#     'commentStartDate': '2020-06-08T04:00:00Z',
#     'openForComment': False,
#     'objectId': '090000648463e987'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPP-2015-0736-0009'}},
#   {'id': 'EPA-HQ-OPPT-2019-0501-0116',
#    'type': 'documents',
#    'attributes': {'documentType': 'Notice',
#     'lastModifiedDate': '2021-01-04T14:04:32Z',
#     'highlightedContent': '',
#     'frDocNum': '2020-29109',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Asbestos (Part 1: Chrysotile Asbestos); Final Toxic Substances Control Act (TSCA) Risk Evaluation; Notice of Availability',
#     'postedDate': '2021-01-04T05:00:00Z',
#     'docketId': 'EPA-HQ-OPPT-2019-0501',
#     'subtype': 'Notice of Data Availability',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849db079'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPPT-2019-0501-0116'}},
#   {'id': 'EPA-HQ-OPP-2010-0979-0014',
#    'type': 'documents',
#    'attributes': {'documentType': 'Notice',
#     'lastModifiedDate': '2021-01-06T02:02:54Z',
#     'highlightedContent': '',
#     'frDocNum': '2020-24524',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': '2021-01-05T04:59:59Z',
#     'title': 'Pesticide Registration Review: Draft Human Health and/or Ecological Risk Assessments for Several Pesticides',
#     'postedDate': '2020-11-05T05:00:00Z',
#     'docketId': 'EPA-HQ-OPP-2010-0979',
#     'subtype': None,
#     'commentStartDate': '2020-11-05T05:00:00Z',
#     'openForComment': False,
#     'objectId': '090000648494cee6'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPP-2010-0979-0014'}},
#   {'id': 'EPA-R08-OAR-2021-0012-0001',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:08:39Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Ruby 31-30H Pad_Title V Application Package',
#     'postedDate': '2021-01-05T05:00:00Z',
#     'docketId': 'EPA-R08-OAR-2021-0012',
#     'subtype': None,
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849def72'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-R08-OAR-2021-0012-0001'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0123',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:59:29Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Memorandum to Mike McTaggart, DFC Ceramics, Incorporated from Richard Marinshaw, Senior Environmental Engineer, Midwest Research Institute (MRI) re: correction to attachment 1 of the information collection request (ICR) [A-2000-50-II-C-48]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baf4b'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0123'}},
#   {'id': 'EPA-HQ-OPP-2015-0474-0044',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:47:03Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Whole Sediment Chronic Toxicity, Freshwater Invertebrates Non-Guideline',
#     'postedDate': '2021-01-05T05:00:00Z',
#     'docketId': 'EPA-HQ-OPP-2015-0474',
#     'subtype': 'Study',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '0900006484971841'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPP-2015-0474-0044'}},
#   {'id': 'EPA-HQ-OPP-2015-0406-0029',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:45:49Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Ethofumesate (110601):  Use, Usage, Benefits Information and Potential Impacts from Mitigation',
#     'postedDate': '2021-01-05T05:00:00Z',
#     'docketId': 'EPA-HQ-OPP-2015-0406',
#     'subtype': 'Report',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849a6d8c'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OPP-2015-0406-0029'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0111',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:46:06Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Charles Marvin, The Refractories Institute from Richard Marinshaw, Midwest Research Institute (MRI) re: the attachment includes the final list of refractory manufacturers to be recipients of the information collection request (ICR) [A-2000-50-II-C-36]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Other',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baf13'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0111'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0115',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:49:31Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Mike McTaggart, DFC Ceramics, Incorporated from Bruce C. Jordan, Director, Emission Standards Division, USEPA re: requests information on DFC Ceramics, Incorporated facilities that manufacture refractories [A-2000-50-II-C-40]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baf28'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0115'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0119',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:56:23Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': "Notes from meeting between representatives of the refractories industry and the USEPA's (USEPA) Office of Air Quality Planning and Standards (OAQPS).  Place: USEPA. OAQPS,10th Floor Conference Room, North Carolina (NC) Mutual Life Building, Durham, NC [A-2000-50-II-C-44]",
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Meeting or Teleconference Materials',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baf39'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0119'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0122',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:58:45Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Thermal Ceramics Company from Richard Marinshaw, Midwest Research Institute re: Information Collection Request (ICR) attachment correction [A-2000-50-II-C-47]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baf47'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0122'}},
#   {'id': 'EPA-R09-OAR-2019-0471-0009',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T02:08:58Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Final Treatment as State (TAS) Documents July 2020',
#     'postedDate': '2021-01-05T05:00:00Z',
#     'docketId': 'EPA-R09-OAR-2019-0471',
#     'subtype': None,
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064849dee4f'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-R09-OAR-2019-0471-0009'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0063',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T00:45:41Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Memorandum to Richard Marinshaw, from Susan Zapata, EPA, Emissions Standards Division [A-2000-50-II-B-032]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bae37'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0063'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0070',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T00:54:31Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Trip Report: Vesuvius USA, Charleston, Illinois, on September 24, 1998 [A-2000-50-II-B-039]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Report',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bae51'},
# ...
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800badd0'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0040'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0031',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T23:14:22Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Source Category Survey; Refractory Industry [EPA-450/3-80-006] [A-2000-50-II-A-001]',
#     'postedDate': '2002-02-02T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Report',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bad91'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0031'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0045',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T23:33:54Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Memorandum to Susan Fairchild-Zapata, USEPA, from Richard Marinshaw and Janet Marron, Midwest Research Institute (MRI), re: Risk Assessment Input Data for North American Refractories Company (NARCO), Womelsdorf Facility Maximum Technology Standard [A-2000-50 II-B-013]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bade8'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0045'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0425',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T18:05:35Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Bruce Jordan, Director, and Susan Zapata, Emissions Standards Division, USEPA from Thomas F. Turpin, Corporate Environmental Manager, American Premier, Inc.; re: Information Collection Request (ICR) for Refractories Manufactures Operations [A-2000-50-II-D-221]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Public Comment',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bb6f2'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0425'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0424',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T18:08:26Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'BMI France Snow Shoe Plant- Section 3 (continued) Material Safety Data Sheets Products and Additives and Section 4 Title V Permit Application (continued) [A-2000-50-II-D-213]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Public Comment',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bb6e4'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0424'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0429',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T18:03:27Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter and supporting documents to B. Jordan and S. Zapata, Emissions Standards Division, USEPA from K. D. Schmidt, Equipment Engineer, Zircoa; re: response to Section 114 information collection request for facility in Solon, Ohio [A-2000-50-II-D-223]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Public Comment',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bb744'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0429'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0452',
#    'type': 'documents',
#    'attributes': {'documentType': 'Rule',
#     'lastModifiedDate': '2021-01-05T20:11:55Z',
#     'highlightedContent': '',
#     'frDocNum': '06-03545',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'National Emission Standards for Hazardous Air Pollutants for Refractory Products Manufacturing; Withdrawal of Direct Final Rule',
#     'postedDate': '2006-04-14T14:28:51Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Federal Register Document',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '090000648015d5e3'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0452'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0015',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T19:37:50Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Marinshaw, R., RTI, to Devroy, D., MEGTEC Systems. Telecon: Information on checking the activity level of catalytic oxidizer catalysts [A-2000-50-IV-E-01]',
#     'postedDate': None,
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Report',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bad35'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0015'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0012',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-05T19:15:53Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Shaver, S., EPA/ESD, to Corlius, R., The Refractories Institute. response to Freedom of Information Act request for the names of refractory products manufacturing facilities [A-2000-50-IV-C-01]',
#     'postedDate': None,
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bad26'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0012'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0089',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:20:33Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Correspondence to Kim Nelson, North American Refractories Company from Rick Marinshaw, Midwest Research Institute re: Types of information needed for the risk assessment [A-2000-50-II-C-14]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baead'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0089'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0097',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:28:48Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Kim A. Nelson, Corporate Manager of Safety and Health, North American Refractories Company (NARCO), from James Crowder, Group Leader, USEPA, re: final versions of the trip report for July 30, 1996 to NARCO [A-2000-50-II-C-22]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800baed1'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0097'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0056',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T00:35:24Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Memorandum to Susan Zapata, ESD, USEPA from Jennifer Spaight and Richard Marinshaw, MRI re: Site Visit, Whitacre Greer Fireproofing Company, Alliance, OH, (MACT) Standards Support for the Refractories Manufacturing Industry [A-2000-50-II-B-024]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Report',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bae19'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0056'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0075',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T01:00:47Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Letter to Susan Zapata EPA/ESD/MICG from Richard Marinshaw and Jennifer Fields, Midwest Research Institute re: Recommended Control Efficiencies for Estimating Baseline Hazardous Air Pollutants (HAP) Emissions and Emission Reductions [A-2000-50-II-B-050]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Letter, Memorandum, Email',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bae6b'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0075'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0069',
#    'type': 'documents',
#    'attributes': {'documentType': 'Supporting & Related Material',
#     'lastModifiedDate': '2021-01-06T00:53:53Z',
#     'highlightedContent': '',
#     'frDocNum': None,
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'commentEndDate': None,
#     'title': 'Trip Report: Vesuvius USA, Hillsboro, Texas, on September 23, 1998 [A-2000-50-II-B-038]',
#     'postedDate': '2002-02-08T05:00:00Z',
#     'docketId': 'EPA-HQ-OAR-2002-0088',
#     'subtype': 'Report',
#     'commentStartDate': None,
#     'openForComment': False,
#     'objectId': '09000064800bae4f'},
#    'links': {'self': 'https://api.regulations.gov/v4/documents/EPA-HQ-OAR-2002-0088-0069'}}],
#  'meta': {'aggregations': {'documentType': [{'docCount': 267,
#      'label': 'Supporting & Related Material'},
#     {'docCount': 17, 'label': 'Notice'},
#     {'docCount': 8, 'label': 'Rule'},
#     {'docCount': 4, 'label': 'Proposed Rule'},
#     {'docCount': 3, 'label': 'Other'}],
#    'subtype': [{'docCount': 131, 'label': 'Letter, Memorandum, Email'},
#     {'docCount': 32, 'label': 'Public Comment'},
#     {'docCount': 21, 'label': 'Report'},
#     {'docCount': 17, 'label': 'Evaluation'},
#     {'docCount': 13, 'label': 'Other'},
#     {'docCount': 6, 'label': 'Publication - Copyrighted Materials'},
#     {'docCount': 5, 'label': 'Memorandum'},
#     {'docCount': 4, 'label': 'Comment Response'},
#     {'docCount': 3, 'label': 'Final Rule'},
#     {'docCount': 3, 'label': 'Meeting or Teleconference Materials'},
#     {'docCount': 2, 'label': 'Federal Register Document'},
#     {'docCount': 2, 'label': 'Interagency Review'},
#     {'docCount': 2, 'label': 'Meeting Materials'},
#     {'docCount': 2, 'label': 'Memorandum to Open a Docket'},
#     {'docCount': 2, 'label': 'Risk Assessment'},
#     {'docCount': 2, 'label': 'Study'},
#     {'docCount': 1, 'label': 'Agreement, Contract'},
#     {'docCount': 1, 'label': 'Analysis'},
#     {'docCount': 1, 'label': 'Correction'},
#     {'docCount': 1, 'label': 'Data'},
#     {'docCount': 1, 'label': 'Decision'},
#     {'docCount': 1, 'label': 'Decree'},
#     {'docCount': 1, 'label': 'Information Collection Request (ICR)'},
#     {'docCount': 1, 'label': 'Letter'},
#     {'docCount': 1, 'label': 'Notice of Data Availability'},
#     {'docCount': 1, 'label': 'Publication'},
#     {'docCount': 1, 'label': 'Publication - USEPA'}],
#    'withinCommentPeriod': [{'docCount': 0, 'label': 'true'},
#     {'docCount': 299, 'label': 'false'}],
#    'agencyId': [{'docCount': 299, 'value': 'EPA'},
#     {'docCount': 49, 'value': 'FAA'},
#     {'docCount': 34, 'value': 'FDA'},
#     {'docCount': 20, 'value': 'SEC'},
#     {'docCount': 18, 'value': 'DOT'},
#     {'docCount': 14, 'value': 'FERC'},
#     {'docCount': 13, 'value': 'ITA'},
#     {'docCount': 9, 'value': 'FMCSA'},
#     {'docCount': 9, 'value': 'FWS'},
#     {'docCount': 9, 'value': 'PHMSA'},
#     {'docCount': 8, 'value': 'NRC'},
#     {'docCount': 7, 'value': 'CMS'},
#     {'docCount': 7, 'value': 'ED'},
#     {'docCount': 7, 'value': 'NHTSA'},
#     {'docCount': 6, 'value': 'APHIS'},
#     {'docCount': 6, 'value': 'FRA'},
#     {'docCount': 6, 'value': 'USCG'},
#     {'docCount': 5, 'value': 'DHS'},
#     {'docCount': 5, 'value': 'DOS'},
#     {'docCount': 5, 'value': 'PTO'},
#     {'docCount': 4, 'value': 'DARS'},
#     {'docCount': 4, 'value': 'EERE'},
#     {'docCount': 4, 'value': 'FAR'},
#     {'docCount': 4, 'value': 'FRS'},
#     {'docCount': 4, 'value': 'OSM'},
#     {'docCount': 4, 'value': 'SSA'},
#     {'docCount': 4, 'value': 'USCIS'},
#     {'docCount': 3, 'value': 'CRC'},
#     {'docCount': 3, 'value': 'DOL'},
#     {'docCount': 3, 'value': 'OSHA'},
#     {'docCount': 3, 'value': 'VA'},
#     {'docCount': 2, 'value': 'CFTC'},
#     {'docCount': 2, 'value': 'CPSC'},
#     {'docCount': 2, 'value': 'CRB'},
#     {'docCount': 2, 'value': 'DEA'},
#     {'docCount': 2, 'value': 'FEMA'},
#     {'docCount': 2, 'value': 'FNS'},
#     {'docCount': 2, 'value': 'FTA'},
#     {'docCount': 2, 'value': 'FTC'},
#     {'docCount': 2, 'value': 'GAO'},
#     {'docCount': 2, 'value': 'HHS'},
#     {'docCount': 2, 'value': 'ITC'},
#     {'docCount': 2, 'value': 'MARAD'},
#     {'docCount': 2, 'value': 'NOAA'},
#     {'docCount': 2, 'value': 'OPM'},
#     {'docCount': 2, 'value': 'USPS'},
#     {'docCount': 1, 'value': 'ATBCB'},
#     {'docCount': 1, 'value': 'BOEM'},
#     {'docCount': 1, 'value': 'CDC'},
#     {'docCount': 1, 'value': 'CFPB'},
#     {'docCount': 1, 'value': 'DOD'},
#     {'docCount': 1, 'value': 'DOE'},
#     {'docCount': 1, 'value': 'EEOC'},
#     {'docCount': 1, 'value': 'EIB'},
#     {'docCount': 1, 'value': 'FCA'},
#     {'docCount': 1, 'value': 'FCC'},
#     {'docCount': 1, 'value': 'FDIC'},
#     {'docCount': 1, 'value': 'FHWA'},
#     {'docCount': 1, 'value': 'GSA'},
#     {'docCount': 1, 'value': 'HUD'},
#     {'docCount': 1, 'value': 'IRS'},
#     {'docCount': 1, 'value': 'NCUA'},
#     {'docCount': 1, 'value': 'NPS'},
#     {'docCount': 1, 'value': 'NTSB'},
#     {'docCount': 1, 'value': 'OCC'},
#     {'docCount': 1, 'value': 'OFAC'},
#     {'docCount': 1, 'value': 'OMB'},
#     {'docCount': 1, 'value': 'TTB'},
#     {'docCount': 1, 'value': 'USBC'},
#     {'docCount': 1, 'value': 'USDA'},
#     {'docCount': 1, 'value': 'USTR'},
#     {'docCount': 1, 'value': 'WHD'}],
#    'commentEndDate': [],
#    'postedDate': []},
#   'filters': {'lastModifiedDate': {'fromDate': '2021-01-01 00:00:00',
#     'toDate': '2021-01-05 23:59:59'},
#    'agencyId': [{'label': 'EPA', 'value': 'EPA'}]},
#   'hasNextPage': True,
#   'hasPreviousPage': False,
#   'numberOfElements': 250,
#   'pageNumber': 1,
#   'pageSize': 250,
#   'totalElements': 299,
#   'totalPages': 2,
#   'firstPage': True,
#   'lastPage': False}}

# %%
# test comments header response
downloader.get_request_json(f'https://api.regulations.gov/v4/comments',
                         params={"filter[agencyId]": "EPA",
                                 "filter[lastModifiedDate][ge]": "2021-01-01 00:00:00",
                                 "filter[lastModifiedDate][le]": "2021-01-05 23:59:59",})
# Out:
# {'data': [{'id': 'EPA-HQ-OPP-2020-0600-0015',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:06:56Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Ben Hill Griffin, IV, Chief Executive Officer & Chairman of the Board, AgLogic 15GG',
#     'objectId': '09000064849c4578',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0600-0015'}},
#   {'id': 'EPA-HQ-OPP-2018-0258-0189',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:56:26Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Brandon W. Neuschafer, Bryan Cave Leighton Paisner LLP',
#     'objectId': '09000064849d07ef',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2018-0258-0189'}},
#   {'id': 'EPA-HQ-OPP-2015-0433-0047',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:46:27Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Michelle Armstrong, Chair, Oregon Hazelnut Commission',
#     'objectId': '09000064849ccbe8',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0433-0047'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0046',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:52:45Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849dcdd6',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0046'}},
#   {'id': 'EPA-HQ-OPP-2015-0716-0031',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:51:45Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by David Epstein, Vice President for Scientific Affairs, Northwest Horticultural Council (NHC)',
#     'objectId': '09000064849c27dc',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0716-0031'}},
#   {'id': 'EPA-HQ-OPP-2013-0244-0027',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:39:09Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Jonathan Kalmuss-Katz and Michelle Mabson, Earthjustice on behalf of Air Alliance Houston et al.',
#     'objectId': '09000064849c7eb3',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0244-0027'}},
#   {'id': 'EPA-HQ-OPP-2015-0288-0046',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:43:55Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Alfred J. Fournier, Arizona Pest Management Center, University of Arizona',
#     'objectId': '09000064849ddb27',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0288-0046'}},
#   {'id': 'EPA-HQ-OPP-2013-0779-0036',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:40:42Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Michael J. Aerts, Director, Science and Regulatory Affairs, Florida Fruit and Vegetable Association (FFVA)',
#     'objectId': '09000064849ce2ea',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0779-0036'}},
#   {'id': 'EPA-HQ-OLEM-2020-0462-0155',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:34:51Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by George A. Kerchner, Executive Director, The Rechargeable Battery Association (PRBA)',
#     'objectId': '09000064849dcf08',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OLEM-2020-0462-0155'}},
#   {'id': 'EPA-HQ-OLEM-2020-0462-0152',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:34:32Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by W. Sagar et al.',
#     'objectId': '09000064849dce67',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OLEM-2020-0462-0152'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0046',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:03:46Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849c395d',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0046'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0037',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:06:19Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849b08ce',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0037'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0042',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:53:18Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849da5ad',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0042'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0035',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:05:13Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849af6f6',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0035'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0033',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:04:19Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by by M. H. (no surname provided)',
#     'objectId': '090000648499fc61',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0033'}},
#   {'id': 'EPA-HQ-OPP-2018-0053-0047',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:55:09Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Nathan Donley, Senior Scientist, Environmental Health Program and Jess Tyler, Staff Scientist, Environmental Health Program, Center for Biological Diversity',
#     'objectId': '090000648497e248',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2018-0053-0047'}},
#   {'id': 'EPA-HQ-OPP-2015-0568-0041',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:50:33Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Michelle Armstrong, Chair, Oregon Hazelnut Commission',
#     'objectId': '09000064849ccc4c',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0568-0041'}},
#   {'id': 'EPA-HQ-OPP-2018-0258-0188',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:57:25Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Grant Aldridge, Chief Executive Officer, Locus Agricultural Solutions, LLC',
#     'objectId': '09000064849d002a',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2018-0258-0188'}},
#   {'id': 'EPA-HQ-OPP-2019-0701-0018',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:58:40Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Steven Bennett, Senior Vice President, Scientific & Regulatory Affairs, Household & Commercial Products Association (HCPA)',
#     'objectId': '09000064849dccb2',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2019-0701-0018'}},
#   {'id': 'EPA-HQ-OPP-2020-0147-0010',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:59:32Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Regiane G. Pereira, Senior Manager, Regulatory and Scientific Affairs, Nichino America Inc.',
#     'objectId': '09000064849c28e1',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0147-0010'}},
#   {'id': 'EPA-HQ-OPP-2009-0209-0039',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-04T20:31:40Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Marisa C. Ordonia and Patti A. Goldman, Earthjustice on behalf of California Rural Legal Assistance Foundation et al. (Part 2 of 3)',
#     'objectId': '0900006484955939',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2009-0209-0039'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0039',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:39:37Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d59bf',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0039'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0032',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:40:19Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d44ae',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0032'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0043',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:02:00Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849b38f3',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0043'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0047',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:05:29Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849c4575',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0047'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0048',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:05:46Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849c57a4',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0048'}},
#   {'id': 'EPA-HQ-OPP-2013-0779-0037',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:40:07Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Doug Noem, President and Lisa Richardson, Executive Director, South Dakota Corn Growers Association',
#     'objectId': '09000064849ba97a',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0779-0037'}},
#   {'id': 'EPA-HQ-OPP-2013-0779-0033',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:41:23Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Brent Rogers, President, Kansas Corn Growers Association (KCGA)',
#     'objectId': '09000064849b77e8',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0779-0033'}},
#   {'id': 'EPA-HQ-OPP-2015-0144-0026',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:42:19Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Cameron Douglass, Acting Director for Sheryl H. Kunickis, Office of Pest Management Policy, United States Department of Agriculture (USDA)',
#     'objectId': '09000064849a6164',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0144-0026'}},
#   {'id': 'EPA-HQ-OPP-2013-0154-0124',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:37:58Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Val Dolcini, Director, California Department of Pesticide Regulation (DPR) and Lauren Zeise, Director, Office of Environmental Health Hazard Assessment (OEHHA)',
#     'objectId': '09000064849be846',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0154-0124'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0040',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:53:02Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by H. Tiefer',
#     'objectId': '09000064849d7937',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0040'}},
#   {'id': 'EPA-HQ-OLEM-2020-0508-0025',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:35:46Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d5d6b',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OLEM-2020-0508-0025'}},
#   {'id': 'EPA-HQ-SFUND-1990-0010-0166',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T23:06:32Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Stephen Bachman, Senior Park & Recreation Specialist, California State Parks',
#     'objectId': '09000064849d02f6',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-SFUND-1990-0010-0166'}},
#   {'id': 'EPA-HQ-SFUND-1990-0010-0167',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T23:06:33Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Mike Weaver, Co-Chair, Fort Ord Community Advisory Group (FOCAG)',
#     'objectId': '09000064849dc84e',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-SFUND-1990-0010-0167'}},
#   {'id': 'EPA-HQ-OW-2018-0640-0656',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:53:45Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by L. Williams',
#     'objectId': '09000064849bbe32',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OW-2018-0640-0656'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0033',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:38:09Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d4cd0',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0033'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0038',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:37:48Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d5961',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0038'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0045',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:54:00Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by V. Jaffett',
#     'objectId': '09000064849dadbd',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0045'}},
#   {'id': 'EPA-HQ-OPP-2015-0568-0039',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:49:52Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Kathryn Homa, IR-4 Project',
#     'objectId': '09000064849c886d',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0568-0039'}},
#   {'id': 'EPA-HQ-OPP-2015-0716-0033',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:50:51Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Corteva AgriScience',
#     'objectId': '09000064849c8f16',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0716-0033'}},
#   {'id': 'EPA-HQ-OPP-2015-0716-0032',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:51:09Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Kathryn Homa, Fungicide Coordinator, IR-4 Project',
#     'objectId': '09000064849c8867',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0716-0032'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0035',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:38:29Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d4eff',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0035'}},
#   {'id': 'EPA-HQ-OPP-2020-0529-0016',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:00:42Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Ian Bartlett, Manager, Regulatory Affairs and Laura Gage, Senior Microbiologist, Solvay USA Inc.',
#     'objectId': '09000064849d2022',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0529-0016'}},
#   {'id': 'EPA-HQ-OPP-2015-0716-0034',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:51:27Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by David Epstein, Vice President for Scientific Affairs, Northwest Horticultural Council (NHC)',
#     'objectId': '09000064849cf91a',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0716-0034'}},
#   {'id': 'EPA-HQ-OPP-2018-0258-0194',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:57:42Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Jolanta Ozatalay, Regulatory Manager, Fine Agrochemicals Ltd',
#     'objectId': '09000064849d2929',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2018-0258-0194'}},
#   {'id': 'EPA-HQ-OPP-2018-0258-0193',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:57:07Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by James M. Skillen, Lawn and Horticultural Products Work Group (LHWPG)',
#     'objectId': '09000064849d1f17',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2018-0258-0193'}},
#   {'id': 'EPA-HQ-OPP-2012-0413-0113',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:37:05Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Julie A. Chao, Acting Director for Sheryl H. Kunickis,Office of Pest Management Policy, United States Department of Agriculture (USDA)',
#     'objectId': '09000064849b07b4',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2012-0413-0113'}},
#   {'id': 'EPA-HQ-OPP-2013-0598-0045',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:39:50Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Nathan Donley, Senior Scientist and Stephanie M. Parent, Senior Attorney, Environmental Health Program, Center for Biological Diversity',
#     'objectId': '09000064849b1689',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0598-0045'}},
#   {'id': 'EPA-HQ-OPP-2013-0598-0044',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:39:33Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Kirk Shermer, President, Snowden Enterprises, Inc.',
#     'objectId': '09000064849b1610',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0598-0044'}},
#   {'id': 'EPA-HQ-OA-2018-0259-22421',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:33:31Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comments submitted by Ben Levitan, Senior Attorney, U.S. Clean Air, Environmental Defense Fund (EDF)',
#     'objectId': '09000064849d479e',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OA-2018-0259-22421'}},
#   {'id': 'EPA-HQ-OPP-2013-0779-0034',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:41:05Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Randy DeSutter, President, Illinois Corn Growers Association (ICGA)',
#     'objectId': '09000064849c23e4',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0779-0034'}},
#   {'id': 'EPA-HQ-OPP-2020-0570-0009',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:01:38Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d2886',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0570-0009'}},
#   {'id': 'EPA-HQ-OPP-2013-0156-0039',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:38:33Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d8dd0',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0156-0039'}},
#   {'id': 'EPA-HQ-OPP-2019-0701-0017',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:58:56Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public Comment',
#     'objectId': '09000064849da21b',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2019-0701-0017'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0034',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:04:37Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849af44a',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0034'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0049',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:06:03Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849c9240',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0049'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0036',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:04:53Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849afe10',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0036'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0043',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:53:36Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Bob Sallinger, Conservation Director, Audubon Society of Portland',
#     'objectId': '09000064849d8005',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0043'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0038',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:06:35Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849b1265',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0038'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0041',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:02:33Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849b1843',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0041'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0042',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:03:08Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849b2cbe',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0042'}},
#   {'id': 'EPA-HQ-OPP-2013-0244-0026',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:38:52Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by George Meyer, Vice President of Operations, Elite Spice, Inc.',
#     'objectId': '09000064849c51f2',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0244-0026'}},
#   {'id': 'EPA-HQ-OPP-2014-0772-0074',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:41:41Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by William Frantz, Executive Director, The Cranberry Institute et al.',
#     'objectId': '09000064849cf925',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2014-0772-0074'}},
#   {'id': 'EPA-HQ-OPP-2013-0154-0125',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:38:15Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Robert D. Swamson, Deputy Attorney General\nFor Xavier Becerra, California Attorney General et al.',
#     'objectId': '09000064849b80a1',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0154-0125'}},
#   {'id': 'EPA-HQ-OPP-2015-0401-0034',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:44:20Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Kathryn Homa, Fungicide Coordinator, IR-4 Project',
#     'objectId': '09000064849c8862',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0401-0034'}},
#   {'id': 'EPA-HQ-OPP-2015-0144-0027',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:42:44Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Gary Bahr, Senior Scientist, Natural Resources Assessment Section Manager, Office of the Director, Washington State Department of Agriculture',
#     'objectId': '09000064849bf723',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0144-0027'}},
#   {'id': 'EPA-HQ-OLEM-2020-0508-0026',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:36:09Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d8e57',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OLEM-2020-0508-0026'}},
#   {'id': 'EPA-HQ-OLEM-2020-0462-0153',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:35:10Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Mark J. Pedersen, Assistant Commissioner, Site  Remediation & Waste Management Program, New Jersey Department of Environmental Protection (DEP)',
#     'objectId': '09000064849dce6a',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OLEM-2020-0462-0153'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0041',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:54:17Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d7693',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0041'}},
#   {'id': 'EPA-HQ-OPP-2010-0480-0347',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T13:37:16Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Tom Jarzynka, Senior Director of Quality Assurance, Massey Services',
#     'objectId': '09000064849c5b82',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2010-0480-0347'}},
#   {'id': 'EPA-HQ-OPP-2010-0479-0101',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T13:37:15Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Andrew D. Moore, Chief Executive Officer, National Agricultural Aviation Association (NAAA)',
#     'objectId': '09000064849b8e9d',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2010-0479-0101'}},
#   {'id': 'EPA-HQ-OPP-2010-0751-0053',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T22:04:07Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Andrew D. Moore, Chief Executive Officer, National Agricultural Aviation Association (NAAA)',
#     'objectId': '09000064849b78fd',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2010-0751-0053'}},
#   {'id': 'EPA-HQ-SFUND-1990-0010-0165',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T23:06:31Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Shirley (no surname provided)',
#     'objectId': '09000064849d02f5',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-SFUND-1990-0010-0165'}},
#   {'id': 'EPA-HQ-SFUND-1990-0010-0168',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T23:06:34Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by M. Wright',
#     'objectId': '09000064849dce64',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-SFUND-1990-0010-0168'}},
#   {'id': 'EPA-HQ-OPP-2009-0209-0038',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-04T20:30:13Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Marisa C. Ordonia and Patti A. Goldman, Earthjustice on behalf of California Rural Legal Assistance Foundation et al. (Part 1 of 3)',
#     'objectId': '09000064849550db',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2009-0209-0038'}},
#   {'id': 'EPA-HQ-OPP-2009-0209-0040',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-04T20:32:49Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Marisa C. Ordonia and Patti A. Goldman, Earthjustice on behalf of California Rural Legal Assistance Foundation et al. (Part 3 of 3)',
#     'objectId': '090000648495557a',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2009-0209-0040'}},
#   {'id': 'EPA-HQ-OPP-2015-0568-0040',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:50:10Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Jay W. Pscheidt, Extension Plant Pathology Specialist and Professor of Botany and Plant Pathology, Oregon State\tUniversity',
#     'objectId': '09000064849cb493',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0568-0040'}},
#   {'id': 'EPA-HQ-OPP-2018-0258-0192',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:57:59Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Sean M. McCarty, Director of Governmental Affairs, Helena Agri-Enterprises, LLC',
#     'objectId': '09000064849d2757',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2018-0258-0192'}},
#   {'id': 'EPA-HQ-OPP-2015-0567-0018',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:49:33Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Jay W.Pscheidt, Extension Plant\tPathology Specialist and Professor of Botany and Plant Pathology, Oregon State University',
#     'objectId': '09000064849cb40e',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0567-0018'}},
#   {'id': 'EPA-HQ-OPP-2016-0140-0024',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:54:37Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Nathan Donley, Senior Scientist and Stephanie M. Parent, Senior Attorney, Environmental Health Program, Center for Biological Diversity',
#     'objectId': '09000064849a2c54',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0140-0024'}},
#   {'id': 'EPA-HQ-OPP-2018-0258-0187',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:55:51Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Taw W. Richardson, President & Chief Executive Officer, Earth Ag',
#     'objectId': '09000064849cf805',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2018-0258-0187'}},
#   {'id': 'EPA-HQ-OPP-2015-0433-0048',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:46:45Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Jay W. Pscheidt, Extension Plant Pathology Specialist and Professor of Botany and Plant Pathology, Oregon State University',
#     'objectId': '09000064849cb491',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0433-0048'}},
#   {'id': 'EPA-HQ-OPP-2018-0258-0195',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:55:34Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Greg Cunningham, Director – Regulatory Affairs,\nThe Scotts Miracle-Gro Company (SMG)',
#     'objectId': '09000064849d23a2',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2018-0258-0195'}},
#   {'id': 'EPA-HQ-OW-2018-0640-0657',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:53:22Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by P. Holland',
#     'objectId': '09000064849bbb54',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OW-2018-0640-0657'}},
#   {'id': 'EPA-HQ-OAR-2002-0088-0235',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T17:24:31Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Memorandum to Richard Marinshaw, Midwest Research Institute (MRI) from M.R. Cauffman, Manager, Plant Environmental, North American Refractories Co. (Company); re: correction concerning the location of a stack from T-4 dryer in figure 8',
#     'objectId': '09000064800bb179',
#     'postedDate': '2002-01-28T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OAR-2002-0088-0235'}},
#   {'id': 'EPA-HQ-OW-2018-0640-0658',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:52:59Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by T.  Bachmann',
#     'objectId': '09000064849bbb55',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OW-2018-0640-0658'}},
#   {'id': 'EPA-HQ-OPP-2020-0570-0008',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:01:19Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Samantha S. Miller, US Crop Protection Regulatory Leader, Corteva Agriscience',
#     'objectId': '09000064849ce45a',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0570-0008'}},
#   {'id': 'EPA-HQ-OPP-2020-0529-0015',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:01:01Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Akayla Bracey, Science and Regulatory Manager and Terry Shistar, Board Member, Beyond Pesticides',
#     'objectId': '09000064849c3f3e',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0529-0015'}},
#   {'id': 'EPA-HQ-OPP-2020-0384-0007',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:00:23Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Jess Tyler, Staff Scientist and Nathan Donley, Senior Scientist, Environmental Health Program, Center for Biological Diversity',
#     'objectId': '09000064849aa154',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0384-0007'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0047',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:52:09Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Annoula Wylderich, Nevada State Director, Animal Wellness Action',
#     'objectId': '09000064849cd7e7',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0047'}},
#   {'id': 'EPA-HQ-OPP-2011-0855-0263',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:36:45Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Sherill Huun, Supervising Engineer, Sacramento River Source Water Protection Program, City of Sacramento Department of Utilities',
#     'objectId': '09000064849bb597',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2011-0855-0263'}},
#   {'id': 'EPA-HQ-OPP-2013-0779-0035',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:40:24Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Carl Jardon, Preisdent, Iowa Corn Growers Association (ICGA)',
#     'objectId': '09000064849cde82',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2013-0779-0035'}},
#   {'id': 'EPA-HQ-OPP-2015-0401-0033',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:44:53Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by M. Vaughn',
#     'objectId': '09000064849c66d2',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0401-0033'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0044',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:52:26Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Barry Kent MacKay, Director of Canadian & Special Programs, Born Free USA',
#     'objectId': '09000064849da26d',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0044'}},
#   {'id': 'EPA-HQ-OPP-2020-0260-0009',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:59:51Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Stephanie Binns, Washington Regulatory Affairs Manager, BASF Corporation',
#     'objectId': '09000064849c5487',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0260-0009'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0045',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:03:25Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849c393d',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0045'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0040',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:02:16Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849b1822',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0040'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0039',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:02:50Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849b1b98',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0039'}},
#   {'id': 'EPA-HQ-OPP-2015-0401-0035',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:44:36Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': "Comment submitted by Paul Merry, Owner, Merry's Berries",
#     'objectId': '09000064849d252b',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0401-0035'}},
#   {'id': 'EPA-HQ-OLEM-2020-0527-0004',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:36:27Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Bob Kinghorn, Stellar J Corporation',
#     'objectId': '09000064849da865',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OLEM-2020-0527-0004'}},
#   {'id': 'EPA-HQ-OGC-2020-0569-0003',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:34:07Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d6377',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OGC-2020-0569-0003'}},
#   {'id': 'EPA-HQ-OPP-2018-0258-0190',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:56:45Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by D. Ry Wagner, President & Chief Executive Officer (CEO), AlgaEnergy N.A. Inc.',
#     'objectId': '09000064849d1467',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2018-0258-0190'}},
#   {'id': 'EPA-HQ-OPP-2020-0585-0044',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T02:04:02Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849b6062',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0585-0044'}},
#   {'id': 'EPA-HQ-OPP-2014-0773-0040',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:42:01Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Andrew D. Moore, Chief Executive Officer, National Agricultural Aviation Association (NAAA)',
#     'objectId': '09000064849bb858',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2014-0773-0040'}},
#   {'id': 'EPA-HQ-OPP-2012-0413-0114',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:37:31Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Andrew D. Moore, Chief Executive Officer, National Agricultural Aviation Association (NAAA)',
#     'objectId': '09000064849bae1a',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2012-0413-0114'}},
#   {'id': 'EPA-HQ-OPP-2015-0288-0045',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:43:37Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Sheryl H. Kunickis, Director, United States Department of Agriculture (UDSA)',
#     'objectId': '09000064849dcf67',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2015-0288-0045'}},
#   {'id': 'EPA-HQ-OLEM-2020-0462-0154',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:35:29Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Cheryl Grabham, Materials Management Program Manager, Oregon Department of Environmental Quality (ODEQ)',
#     'objectId': '09000064849dcf05',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OLEM-2020-0462-0154'}},
#   {'id': 'EPA-HQ-OPP-2010-0480-0348',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T13:37:17Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Andrew D. Moore, Chief Executive Officer, National Agricultural Aviation Association (NAAA)',
#     'objectId': '09000064849dbf4e',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2010-0480-0348'}},
#   {'id': 'EPA-HQ-OPP-2010-0480-0349',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T22:04:04Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Gary Bahr, Senior Scientist, Natural Resources Assessment Section Manager, Office of the Director, Washington State Department of Agriculture',
#     'objectId': '09000064849bf798',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2010-0480-0349'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0030',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:39:18Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d4b58',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0030'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0031',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:39:58Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d4c58',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0031'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0034',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:38:51Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by J. Weaver',
#     'objectId': '09000064849d5609',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0034'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0036',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:37:22Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d56a1',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0036'}},
#   {'id': 'EPA-HQ-OPP-2016-0030-0037',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-05T01:37:03Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Anonymous public comment',
#     'objectId': '09000064849d596f',
#     'postedDate': '2021-01-04T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2016-0030-0037'}},
#   {'id': 'EPA-HQ-OPP-2018-0258-0191',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:56:09Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by David Hiltz, Director, Global Regulatory Affairs, Acadian Seaplants Limited (ASL)',
#     'objectId': '09000064849d2588',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2018-0258-0191'}},
#   {'id': 'EPA-HQ-OPP-2019-0701-0016',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:58:19Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Erica Millette, Chair, AAPCO 25(b) Workgroup\nProgram Specialist, New Mexico Department of Agriculture',
#     'objectId': '09000064849b0d6a',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2019-0701-0016'}},
#   {'id': 'EPA-HQ-OPP-2019-0701-0019',
#    'type': 'comments',
#    'attributes': {'documentType': 'Public Submission',
#     'lastModifiedDate': '2021-01-06T01:59:13Z',
#     'highlightedContent': '',
#     'withdrawn': False,
#     'agencyId': 'EPA',
#     'title': 'Comment submitted by Kelle Davis, Program Manager, Registration Services, Washington State Department of Agriculture',
#     'objectId': '09000064849971da',
#     'postedDate': '2021-01-05T05:00:00Z'},
#    'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2019-0701-0019'}}],
#  'meta': {'aggregations': {'agencyId': [{'docCount': 813, 'value': 'OCC'},
#     {'docCount': 768, 'value': 'FDA'},
#     {'docCount': 690, 'value': 'CMS'},
#     {'docCount': 354, 'value': 'VA'},
#     {'docCount': 347, 'value': 'FWS'},
#     {'docCount': 268, 'value': 'APHIS'},
#     {'docCount': 117, 'value': 'EPA'},
#     {'docCount': 85, 'value': 'FMCSA'},
#     {'docCount': 74, 'value': 'HRSA'},
#     {'docCount': 38, 'value': 'MARAD'},
#     {'docCount': 30, 'value': 'FAA'},
#     {'docCount': 30, 'value': 'HHS'},
#     {'docCount': 18, 'value': 'CFPB'},
#     {'docCount': 18, 'value': 'DEA'},
#     {'docCount': 18, 'value': 'FHWA'},
#     {'docCount': 18, 'value': 'NRC'},
#     {'docCount': 15, 'value': 'ED'},
#     {'docCount': 14, 'value': 'NHTSA'},
#     {'docCount': 13, 'value': 'HUD'},
#     {'docCount': 10, 'value': 'NCUA'},
#     {'docCount': 9, 'value': 'FINCEN'},
#     {'docCount': 7, 'value': 'NOAA'},
#     {'docCount': 7, 'value': 'OSHA'},
#     {'docCount': 6, 'value': 'COE'},
#     {'docCount': 6, 'value': 'DHS'},
#     {'docCount': 6, 'value': 'IRS'},
#     {'docCount': 6, 'value': 'PHMSA'},
#     {'docCount': 5, 'value': 'USCIS'},
#     {'docCount': 4, 'value': 'USCG'},
#     {'docCount': 3, 'value': 'FRA'},
#     {'docCount': 2, 'value': 'AMS'},
#     {'docCount': 2, 'value': 'DOD'},
#     {'docCount': 2, 'value': 'EERE'},
#     {'docCount': 2, 'value': 'NLRB'},
#     {'docCount': 2, 'value': 'PTO'},
#     {'docCount': 2, 'value': 'TTB'},
#     {'docCount': 2, 'value': 'USTR'},
#     {'docCount': 1, 'value': 'ASC'},
#     {'docCount': 1, 'value': 'BIS'},
#     {'docCount': 1, 'value': 'CDC'},
#     {'docCount': 1, 'value': 'CPSC'},
#     {'docCount': 1, 'value': 'DOT'},
#     {'docCount': 1, 'value': 'EOIR'},
#     {'docCount': 1, 'value': 'FEMA'},
#     {'docCount': 1, 'value': 'USCBP'}],
#    'postedDate': []},
#   'filters': {'lastModifiedDate': {'fromDate': '2021-01-01 00:00:00',
#     'toDate': '2021-01-05 23:59:59'},
#    'agencyId': [{'label': 'EPA', 'value': 'EPA'}]},
#   'hasNextPage': False,
#   'hasPreviousPage': False,
#   'numberOfElements': 117,
#   'pageNumber': 1,
#   'pageSize': 250,
#   'totalElements': 117,
#   'totalPages': 1,
#   'firstPage': True,
#   'lastPage': True}}

# %%
# test comments details response
downloader.get_request_json(f'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0600-0015',
                         params=None)
# Out:
# {'data': {'id': 'EPA-HQ-OPP-2020-0600-0015',
#   'type': 'comments',
#   'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0600-0015'},
#   'attributes': {'commentOn': '0900006484989bcd',
#    'commentOnDocumentId': 'EPA-HQ-OPP-2020-0600-0001',
#    'duplicateComments': 1,
#    'address1': None,
#    'address2': None,
#    'agencyId': 'EPA',
#    'city': None,
#    'category': None,
#    'comment': 'EPA-HQ-OPP-2020-0600<br/>Aldicarb proposed new crop uses FL orange and grapefruit',
#    'country': None,
#    'displayProperties': [{'name': 'pageCount',
#      'label': 'Page Count',
#      'tooltip': 'Number of pages In the content file'}],
#    'docAbstract': None,
#    'docketId': 'EPA-HQ-OPP-2020-0600',
#    'documentType': 'Public Submission',
#    'email': None,
#    'fax': None,
#    'field1': None,
#    'field2': None,
#    'fileFormats': None,
#    'firstName': None,
#    'govAgency': None,
#    'govAgencyType': None,
#    'objectId': '09000064849c4578',
#    'lastName': None,
#    'legacyId': None,
#    'modifyDate': '2021-01-06T02:06:56Z',
#    'organization': None,
#    'originalDocumentId': None,
#    'pageCount': 1,
#    'phone': None,
#    'postedDate': '2021-01-05T05:00:00Z',
#    'postmarkDate': '2020-12-23T05:00:00Z',
#    'reasonWithdrawn': None,
#    'receiveDate': '2020-12-23T05:00:00Z',
#    'restrictReason': None,
#    'restrictReasonType': None,
#    'stateProvinceRegion': None,
#    'submitterRep': None,
#    'submitterRepAddress': None,
#    'submitterRepCityState': None,
#    'subtype': 'Company/Organization Comment',
#    'title': 'Comment submitted by Ben Hill Griffin, IV, Chief Executive Officer & Chairman of the Board, AgLogic 15GG',
#    'trackingNbr': '1k4-9kt6-a4gb',
#    'withdrawn': False,
#    'zip': None,
#    'openForComment': False},
#   'relationships': {'attachments': {'links': {'self': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0600-0015/relationships/attachments',
#      'related': 'https://api.regulations.gov/v4/comments/EPA-HQ-OPP-2020-0600-0015/attachments'}}}}}

# %%
# test dockets header response
j = downloader.get_request_json(f'https://api.regulations.gov/v4/dockets',
                         params={"filter[agencyId]": "EPA",
                                 "filter[lastModifiedDate][ge]": "2021-01-01 00:00:00",
                                 "filter[lastModifiedDate][le]": "2021-01-05 23:59:59",})

j['data'][0]['attributes']
# Out:
# {'docketType': 'Nonrulemaking',
#  'lastModifiedDate': '2021-01-05T08:37:37Z',
#  'highlightedContent': None,
#  'agencyId': 'EPA',
#  'title': 'Pesticide Registration  Review for Zinc Phosphide',
#  'objectId': '0b00006481e9d9e4'}

# %% [markdown]
# # Test get_items_count

# %%
# get count documents header response
downloader.get_items_count("documents", params={"filter[agencyId]": "EPA",
                                 "filter[lastModifiedDate][ge]": "2019-01-01 00:00:00",
                                 "filter[lastModifiedDate][le]": "2019-02-28 23:59:59",})
# Out:
# 2116

# %% [markdown]
# ## without trailing s

# %%
# get count dockets header response
downloader.get_items_count("docket", params={"filter[agencyId]": "EPA",})
# Out:
# 18041

# %%
# get count documents header response
downloader.get_items_count("document", params={"filter[agencyId]": "EPA",
                                                "filter[postedDate][ge]": "2019-01-01",
                                                "filter[postedDate][le]": "2019-06-30",})
# Out:
# 8038

# %%
# get count comments header response
downloader.get_items_count("comment", params={"filter[agencyId]": "EPA",
                                                "filter[postedDate][ge]": "2019-01-01",
                                                "filter[postedDate][le]": "2019-03-30",})
# Out:
# 6152

# %% [markdown]
# # Test gather_headers

# %% [markdown]
# ## dockets

# %%
# get count dockets header response
downloader.get_items_count("dockets", params={"filter[agencyId]": "EPA",})
# Out:
# 18041

# %%
downloader.gather_headers("dockets", params={"filter[agencyId]": "EPA"}, db_filename="testdb.db")
# Out:
# Found 18041 dockets...
#
# Enter outer loop (0 dockets collected)...
#     250 dockets retrieved
#     500 dockets retrieved
#     750 dockets retrieved
#     1000 dockets retrieved
#     1250 dockets retrieved
#     1500 dockets retrieved
#     1750 dockets retrieved
#     2000 dockets retrieved
#     2250 dockets retrieved
#     2500 dockets retrieved
#     2750 dockets retrieved
#     3000 dockets retrieved
#     3250 dockets retrieved
#     3500 dockets retrieved
#     3750 dockets retrieved
#     4000 dockets retrieved
#     4250 dockets retrieved
#     4500 dockets retrieved
#     4750 dockets retrieved
#     5000 dockets retrieved
# 2021-05-27 11:10:39: Inserting 5000 records into database...
#
# Enter outer loop (5000 dockets collected)...
#     5250 dockets retrieved
#     5500 dockets retrieved
#     5750 dockets retrieved
#     6000 dockets retrieved
#     6250 dockets retrieved
#     6500 dockets retrieved
#     6750 dockets retrieved
#     7000 dockets retrieved
#     7250 dockets retrieved
#     7500 dockets retrieved
#     7750 dockets retrieved
#     8000 dockets retrieved
#     8250 dockets retrieved
#     8500 dockets retrieved
#     8750 dockets retrieved
#     9000 dockets retrieved
#     9250 dockets retrieved
#     9500 dockets retrieved
#     9750 dockets retrieved
#     10000 dockets retrieved
# 2021-05-27 11:10:48: Inserting 5000 records into database...
#
# Enter outer loop (10000 dockets collected)...
#     10250 dockets retrieved
#     10500 dockets retrieved
#     10750 dockets retrieved
#     11000 dockets retrieved
#     11250 dockets retrieved
#     11500 dockets retrieved
#     11750 dockets retrieved
#     12000 dockets retrieved
#     12250 dockets retrieved
#     12500 dockets retrieved
#     12750 dockets retrieved
#     13000 dockets retrieved
#     13250 dockets retrieved
#     13500 dockets retrieved
#     13750 dockets retrieved
#     14000 dockets retrieved
# (Requests left: 700)
#     14250 dockets retrieved
#     14500 dockets retrieved
#     14750 dockets retrieved
#     15000 dockets retrieved
# 2021-05-27 11:10:56: Inserting 5000 records into database...
#
# Enter outer loop (15000 dockets collected)...
#     15250 dockets retrieved
#     15500 dockets retrieved
#     15750 dockets retrieved
#     16000 dockets retrieved
#     16250 dockets retrieved
#     16500 dockets retrieved
#     16750 dockets retrieved
#     17000 dockets retrieved
#     17250 dockets retrieved
#     17500 dockets retrieved
#     17750 dockets retrieved
#     18000 dockets retrieved
#     18044 dockets retrieved
# 2021-05-27 11:11:01: Inserting 3044 records into database...
# 2021-05-27 11:11:01: Finished: approximately 18044 dockets collected

# %%
with sqlite3.connect("testdb.db") as conn:
    x = pd.read_sql_query('select count(*) from dockets_header', conn)
x
# Out:
#    count(*)
# 0     18041

# %%
with sqlite3.connect("testdb.db") as conn:
    x = pd.read_sql_query('select * from dockets_header limit 5', conn)
x
# Out:
#                    docketId agencyId     docketType  \
# 0  EPA-R06-OAR-2005-TX-0034      EPA  Nonrulemaking
# 1  EPA-R06-OAR-2004-TX-0004      EPA  Nonrulemaking
# 2     EPA-R10-OAR-2007-0411      EPA  Nonrulemaking
# 3     EPA-R10-OAR-2008-0130      EPA  Nonrulemaking
# 4    EPA-R03-RCRA-2008-0256      EPA  Nonrulemaking
#
#                                                title      lastModifiedDate  \
# 0  TX040 Texas: National Emission Standards for H...  2007-09-22T09:17:31Z
# 1  TX004 Texas: National Emission Standards for H...  2007-09-22T09:20:29Z
# 2  ICR Renewal 2007; Federal Implementation Plans...  2008-02-26T19:54:20Z
# 3  Announcement of the Delegation of Partial Admi...  2008-04-03T20:18:27Z
# 4  Virginia-Revision to the Final Authorization o...  2008-06-05T09:31:28Z
#
#            objectId              sqltime
# 0  0b000064800a7424  2021-05-27 15:10:39
# 1  0b000064800a9d6f  2021-05-27 15:10:39
# 2  0b0000648023849a  2021-05-27 15:10:39
# 3  0b000064803ad512  2021-05-27 15:10:39
# 4  0b00006480409eac  2021-05-27 15:10:39

# %%
# test with flatfile
downloader.gather_headers("dockets", params={"filter[agencyId]": "EPA"},
                          csv_filename="dockets_test.csv")
# Out:
# Found 18041 dockets...
#
# Enter outer loop (0 dockets collected)...
#     250 dockets retrieved
#     500 dockets retrieved
#     750 dockets retrieved
#     1000 dockets retrieved
#     1250 dockets retrieved
#     1500 dockets retrieved
#     1750 dockets retrieved
#     2000 dockets retrieved
#     2250 dockets retrieved
#     2500 dockets retrieved
#     2750 dockets retrieved
#     3000 dockets retrieved
#     3250 dockets retrieved
#     3500 dockets retrieved
#     3750 dockets retrieved
#     4000 dockets retrieved
#     4250 dockets retrieved
#     4500 dockets retrieved
#     4750 dockets retrieved
#     5000 dockets retrieved
# 2021-05-27 11:11:10: Writing 5000 records to dockets_test.csv...Done
#
# Enter outer loop (5000 dockets collected)...
#     5250 dockets retrieved
#     5500 dockets retrieved
#     5750 dockets retrieved
#     6000 dockets retrieved
#     6250 dockets retrieved
#     6500 dockets retrieved
#     6750 dockets retrieved
#     7000 dockets retrieved
#     7250 dockets retrieved
#     7500 dockets retrieved
#     7750 dockets retrieved
#     8000 dockets retrieved
#     8250 dockets retrieved
#     8500 dockets retrieved
#     8750 dockets retrieved
#     9000 dockets retrieved
#     9250 dockets retrieved
#     9500 dockets retrieved
#     9750 dockets retrieved
#     10000 dockets retrieved
# 2021-05-27 11:12:06: Writing 5000 records to dockets_test.csv...Done
#
# Enter outer loop (10000 dockets collected)...
#     10250 dockets retrieved
#     10500 dockets retrieved
#     10750 dockets retrieved
#     11000 dockets retrieved
#     11250 dockets retrieved
#     11500 dockets retrieved
#     11750 dockets retrieved
#     12000 dockets retrieved
#     12250 dockets retrieved
#     12500 dockets retrieved
#     12750 dockets retrieved
#     13000 dockets retrieved
#     13250 dockets retrieved
#     13500 dockets retrieved
#     13750 dockets retrieved
#     14000 dockets retrieved
#     14250 dockets retrieved
#     14500 dockets retrieved
#     14750 dockets retrieved
#     15000 dockets retrieved
# 2021-05-27 11:12:16: Writing 5000 records to dockets_test.csv...Done
#
# Enter outer loop (15000 dockets collected)...
#     15250 dockets retrieved
#     15500 dockets retrieved
#     15750 dockets retrieved
#     16000 dockets retrieved
#     16250 dockets retrieved
#     16500 dockets retrieved
#     16750 dockets retrieved
#     17000 dockets retrieved
#     17250 dockets retrieved
#     17500 dockets retrieved
#     17750 dockets retrieved
#     18000 dockets retrieved
#     18044 dockets retrieved
# 2021-05-27 11:12:22: Writing 3044 records to dockets_test.csv...Done
# 2021-05-27 11:12:22: Removing any duplicates in the CSV...
# 2021-05-27 11:12:22: Done. Removed 3 duplicate rows from dockets_test.csv.
# 2021-05-27 11:12:22: Finished: approximately 18044 dockets collected

# %% [markdown]
# ### without trailing s

# %%
# also use a database in a subdirectory that doesn't yet exist
downloader.gather_headers("docket", params={"filter[agencyId]": "EPA"}, db_filename="blah/blah/blah.db")
# Out:
# Found 18041 dockets...
#
# Enter outer loop (0 dockets collected)...
#     250 dockets retrieved
#     500 dockets retrieved
#     750 dockets retrieved
#     1000 dockets retrieved
#     1250 dockets retrieved
#     1500 dockets retrieved
#     1750 dockets retrieved
#     2000 dockets retrieved
# (Requests left: 600)
#     2250 dockets retrieved
#     2500 dockets retrieved
#     2750 dockets retrieved
#     3000 dockets retrieved
#     3250 dockets retrieved
#     3500 dockets retrieved
#     3750 dockets retrieved
#     4000 dockets retrieved
#     4250 dockets retrieved
#     4500 dockets retrieved
#     4750 dockets retrieved
#     5000 dockets retrieved
# 2021-05-27 11:12:33: Inserting 5000 records into database...
#
# Enter outer loop (5000 dockets collected)...
#     5250 dockets retrieved
#     5500 dockets retrieved
#     5750 dockets retrieved
#     6000 dockets retrieved
#     6250 dockets retrieved
#     6500 dockets retrieved
#     6750 dockets retrieved
#     7000 dockets retrieved
#     7250 dockets retrieved
#     7500 dockets retrieved
#     7750 dockets retrieved
#     8000 dockets retrieved
#     8250 dockets retrieved
#     8500 dockets retrieved
#     8750 dockets retrieved
#     9000 dockets retrieved
#     9250 dockets retrieved
#     9500 dockets retrieved
#     9750 dockets retrieved
#     10000 dockets retrieved
# 2021-05-27 11:12:43: Inserting 5000 records into database...
#
# Enter outer loop (10000 dockets collected)...
#     10250 dockets retrieved
#     10500 dockets retrieved
#     10750 dockets retrieved
#     11000 dockets retrieved
#     11250 dockets retrieved
#     11500 dockets retrieved
#     11750 dockets retrieved
#     12000 dockets retrieved
#     12250 dockets retrieved
#     12500 dockets retrieved
#     12750 dockets retrieved
#     13000 dockets retrieved
#     13250 dockets retrieved
#     13500 dockets retrieved
#     13750 dockets retrieved
#     14000 dockets retrieved
#     14250 dockets retrieved
#     14500 dockets retrieved
#     14750 dockets retrieved
#     15000 dockets retrieved
# 2021-05-27 11:12:53: Inserting 5000 records into database...
#
# Enter outer loop (15000 dockets collected)...
#     15250 dockets retrieved
#     15500 dockets retrieved
#     15750 dockets retrieved
#     16000 dockets retrieved
#     16250 dockets retrieved
#     16500 dockets retrieved
#     16750 dockets retrieved
#     17000 dockets retrieved
#     17250 dockets retrieved
#     17500 dockets retrieved
#     17750 dockets retrieved
#     18000 dockets retrieved
#     18044 dockets retrieved
# 2021-05-27 11:12:59: Inserting 3044 records into database...
# 2021-05-27 11:12:59: Finished: approximately 18044 dockets collected

# %%
with sqlite3.connect("blah/blah/blah.db") as conn:
    x = pd.read_sql_query('select * from dockets_header limit 5', conn)
x
# Out:
#                    docketId agencyId     docketType  \
# 0  EPA-R06-OAR-2005-TX-0034      EPA  Nonrulemaking
# 1  EPA-R06-OAR-2004-TX-0004      EPA  Nonrulemaking
# 2     EPA-R10-OAR-2007-0411      EPA  Nonrulemaking
# 3     EPA-R10-OAR-2008-0130      EPA  Nonrulemaking
# 4    EPA-R03-RCRA-2008-0256      EPA  Nonrulemaking
#
#                                                title      lastModifiedDate  \
# 0  TX040 Texas: National Emission Standards for H...  2007-09-22T09:17:31Z
# 1  TX004 Texas: National Emission Standards for H...  2007-09-22T09:20:29Z
# 2  ICR Renewal 2007; Federal Implementation Plans...  2008-02-26T19:54:20Z
# 3  Announcement of the Delegation of Partial Admi...  2008-04-03T20:18:27Z
# 4  Virginia-Revision to the Final Authorization o...  2008-06-05T09:31:28Z
#
#            objectId              sqltime
# 0  0b000064800a7424  2021-05-27 15:12:33
# 1  0b000064800a9d6f  2021-05-27 15:12:33
# 2  0b0000648023849a  2021-05-27 15:12:33
# 3  0b000064803ad512  2021-05-27 15:12:33
# 4  0b00006480409eac  2021-05-27 15:12:33

# %%
# repeat, using a flatfile and a subdirectory that doesn't yet exist
downloader.gather_headers("docket", params={"filter[agencyId]": "EPA"}, csv_filename="blah2/blah2/blah2.csv")
# Out:
# Found 18041 dockets...
#
# Enter outer loop (0 dockets collected)...
#     250 dockets retrieved
#     500 dockets retrieved
#     750 dockets retrieved
#     1000 dockets retrieved
#     1250 dockets retrieved
#     1500 dockets retrieved
#     1750 dockets retrieved
#     2000 dockets retrieved
#     2250 dockets retrieved
#     2500 dockets retrieved
#     2750 dockets retrieved
#     3000 dockets retrieved
#     3250 dockets retrieved
#     3500 dockets retrieved
#     3750 dockets retrieved
#     4000 dockets retrieved
#     4250 dockets retrieved
#     4500 dockets retrieved
#     4750 dockets retrieved
#     5000 dockets retrieved
# 2021-05-27 11:13:08: Writing 5000 records to blah2/blah2/blah2.csv...Done
#
# Enter outer loop (5000 dockets collected)...
#     5250 dockets retrieved
#     5500 dockets retrieved
#     5750 dockets retrieved
#     6000 dockets retrieved
#     6250 dockets retrieved
#     6500 dockets retrieved
#     6750 dockets retrieved
#     7000 dockets retrieved
#     7250 dockets retrieved
#     7500 dockets retrieved
#     7750 dockets retrieved
#     8000 dockets retrieved
#     8250 dockets retrieved
#     8500 dockets retrieved
# (Requests left: 500)
#     8750 dockets retrieved
# (Requests left: 500)
#     9000 dockets retrieved
#     9250 dockets retrieved
#     9500 dockets retrieved
#     9750 dockets retrieved
#     10000 dockets retrieved
# 2021-05-27 11:13:16: Writing 5000 records to blah2/blah2/blah2.csv...Done
#
# Enter outer loop (10000 dockets collected)...
#     10250 dockets retrieved
#     10500 dockets retrieved
#     10750 dockets retrieved
#     11000 dockets retrieved
#     11250 dockets retrieved
#     11500 dockets retrieved
#     11750 dockets retrieved
#     12000 dockets retrieved
#     12250 dockets retrieved
#     12500 dockets retrieved
#     12750 dockets retrieved
#     13000 dockets retrieved
#     13250 dockets retrieved
#     13500 dockets retrieved
#     13750 dockets retrieved
#     14000 dockets retrieved
#     14250 dockets retrieved
#     14500 dockets retrieved
#     14750 dockets retrieved
#     15000 dockets retrieved
# 2021-05-27 11:13:24: Writing 5000 records to blah2/blah2/blah2.csv...Done
#
# Enter outer loop (15000 dockets collected)...
#     15250 dockets retrieved
#     15500 dockets retrieved
#     15750 dockets retrieved
#     16000 dockets retrieved
#     16250 dockets retrieved
#     16500 dockets retrieved
#     16750 dockets retrieved
#     17000 dockets retrieved
#     17250 dockets retrieved
#     17500 dockets retrieved
#     17750 dockets retrieved
#     18000 dockets retrieved
#     18044 dockets retrieved
# 2021-05-27 11:13:28: Writing 3044 records to blah2/blah2/blah2.csv...Done
# 2021-05-27 11:13:28: Removing any duplicates in the CSV...
# 2021-05-27 11:13:29: Done. Removed 3 duplicate rows from blah2/blah2/blah2.csv.
# 2021-05-27 11:13:29: Finished: approximately 18044 dockets collected

# %% [markdown]
# ## documents

# %%
# get count documents header response
downloader.get_items_count("documents", params={"filter[agencyId]": "EPA",
                                                "filter[postedDate][ge]": "2019-01-01",
                                                "filter[postedDate][le]": "2019-06-30",})
# Out:
# 8038

# %%
# download to the existing db from above
downloader.gather_headers("documents", params={"filter[agencyId]": "EPA",
                                                "filter[postedDate][ge]": "2019-01-01",
                                                "filter[postedDate][le]": "2019-06-30",},
                          db_filename="testdb.db")
# Out:
# Found 8038 documents...
#
# Enter outer loop (0 documents collected)...
#     250 documents retrieved
#     500 documents retrieved
#     750 documents retrieved
#     1000 documents retrieved
#     1250 documents retrieved
#     1500 documents retrieved
#     1750 documents retrieved
#     2000 documents retrieved
#     2250 documents retrieved
#     2500 documents retrieved
#     2750 documents retrieved
#     3000 documents retrieved
#     3250 documents retrieved
#     3500 documents retrieved
#     3750 documents retrieved
#     4000 documents retrieved
#     4250 documents retrieved
#     4500 documents retrieved
#     4750 documents retrieved
#     5000 documents retrieved
# 2021-05-27 11:13:50: Inserting 5000 records into database...
#
# Enter outer loop (5000 documents collected)...
#     5250 documents retrieved
#     5500 documents retrieved
#     5750 documents retrieved
#     6000 documents retrieved
#     6250 documents retrieved
#     6500 documents retrieved
#     6750 documents retrieved
#     7000 documents retrieved
#     7250 documents retrieved
#     7500 documents retrieved
#     7750 documents retrieved
#     8000 documents retrieved
#     8039 documents retrieved
# 2021-05-27 11:13:59: Inserting 3039 records into database...
# 2021-05-27 11:14:00: Finished: approximately 8039 documents collected

# %%
with sqlite3.connect("testdb.db") as conn:
    x = pd.read_sql_query('select count(*) from documents_header', conn)
x
# Out:
#    count(*)
# 0      8038

# %%
with sqlite3.connect("testdb.db") as conn:
    x = pd.read_sql_query('select * from documents_header where lastModifiedDate is not null limit 10', conn)
x
# Out:
#                    documentId        commentEndDate      commentStartDate  \
# 0  EPA-R01-OAR-2018-0637-0002                  None                  None
# 1  EPA-R08-OAR-2018-0287-0033                  None                  None
# 2  EPA-R08-OAR-2018-0323-0012                  None                  None
# 3  EPA-R08-OAR-2018-0323-0013                  None                  None
# 4  EPA-R08-OAR-2018-0323-0014                  None                  None
# 5  EPA-R08-OAR-2018-0323-0009                  None                  None
# 6  EPA-R08-OAR-2018-0323-0007  2019-03-07T04:59:59Z  2019-01-29T05:00:00Z
# 7  EPA-R08-OAR-2018-0323-0011                  None                  None
# 8  EPA-R08-OAR-2018-0323-0010                  None                  None
# 9  EPA-R08-OAR-2018-0323-0008                  None  2019-01-29T05:00:00Z
#
#                 docketId                   documentType frDocNum  \
# 0  EPA-R01-OAR-2018-0637  Supporting & Related Material     None
# 1  EPA-R08-OAR-2018-0287  Supporting & Related Material     None
# 2  EPA-R08-OAR-2018-0323  Supporting & Related Material     None
# 3  EPA-R08-OAR-2018-0323  Supporting & Related Material     None
# 4  EPA-R08-OAR-2018-0323  Supporting & Related Material     None
# 5  EPA-R08-OAR-2018-0323  Supporting & Related Material     None
# 6  EPA-R08-OAR-2018-0323                          Other     None
# 7  EPA-R08-OAR-2018-0323  Supporting & Related Material     None
# 8  EPA-R08-OAR-2018-0323  Supporting & Related Material     None
# 9  EPA-R08-OAR-2018-0323                          Other     None
#
#        lastModifiedDate          objectId            postedDate subtype  \
# 0  2019-01-29T01:33:40Z  0900006483a186ee  2019-01-28T05:00:00Z    None
# 1  2019-01-29T01:37:09Z  0900006483a1bdb4  2019-01-28T05:00:00Z    None
# 2  2019-01-30T01:36:37Z  0900006483a21ed4  2019-01-29T05:00:00Z    None
# 3  2019-01-30T01:36:54Z  0900006483a21ed5  2019-01-29T05:00:00Z    None
# 4  2019-01-30T01:37:15Z  0900006483a21ed6  2019-01-29T05:00:00Z    None
# 5  2019-01-30T01:37:34Z  0900006483a21eb1  2019-01-29T05:00:00Z    None
# 6  2019-01-30T01:37:53Z  0900006483a21ea9  2019-01-29T05:00:00Z    None
# 7  2019-01-30T01:38:12Z  0900006483a21ed2  2019-01-29T05:00:00Z    None
# 8  2019-01-30T01:38:31Z  0900006483a21ed1  2019-01-29T05:00:00Z    None
# 9  2019-01-30T01:38:49Z  0900006483a21eaa  2019-01-29T05:00:00Z    None
#
#                                                title  withdrawn  \
# 0                     4-19-17 2010 SO2 SIP Submittal          0
# 1           SUIT Comment on SMNSR-SU-000052-2018.002          0
# 2  EJ Memo to File Diablo_AnadarkoDiabloCS_Propos...          0
# 3  ESA Memo to File Diablo_ AnadarkoDiabloCS_Prop...          0
# 4  NHPA Memo to File Diablo_AnadarkoDiabloCS_Prop...          0
# 5  Anadarko Diablo CS Proposed SMNSR Docket Triba...          0
# 6  Anadarko Diablo CS Proposed Permit SMNSR-UO-00...          0
# 7    Anadarko Diablo CS TSD SMNSR-UO-000823-2016.001          0
# 8  Anadarko Diablo CS Proposed SMNSR Public Notic...          0
# 9  Anadarko Diablo CS Proposed SMNSR Transmittal ...          0
#
#                sqltime
# 0  2021-05-27 15:13:50
# 1  2021-05-27 15:13:50
# 2  2021-05-27 15:13:50
# 3  2021-05-27 15:13:50
# 4  2021-05-27 15:13:50
# 5  2021-05-27 15:13:50
# 6  2021-05-27 15:13:50
# 7  2021-05-27 15:13:50
# 8  2021-05-27 15:13:50
# 9  2021-05-27 15:13:50

# %%
# does dockets_header still exist?
with sqlite3.connect("testdb.db") as conn:
    x = pd.read_sql_query('select * from dockets_header limit 5', conn)
x
# Out:
#                    docketId agencyId     docketType  \
# 0  EPA-R06-OAR-2005-TX-0034      EPA  Nonrulemaking
# 1  EPA-R06-OAR-2004-TX-0004      EPA  Nonrulemaking
# 2     EPA-R10-OAR-2007-0411      EPA  Nonrulemaking
# 3     EPA-R10-OAR-2008-0130      EPA  Nonrulemaking
# 4    EPA-R03-RCRA-2008-0256      EPA  Nonrulemaking
#
#                                                title      lastModifiedDate  \
# 0  TX040 Texas: National Emission Standards for H...  2007-09-22T09:17:31Z
# 1  TX004 Texas: National Emission Standards for H...  2007-09-22T09:20:29Z
# 2  ICR Renewal 2007; Federal Implementation Plans...  2008-02-26T19:54:20Z
# 3  Announcement of the Delegation of Partial Admi...  2008-04-03T20:18:27Z
# 4  Virginia-Revision to the Final Authorization o...  2008-06-05T09:31:28Z
#
#            objectId              sqltime
# 0  0b000064800a7424  2021-05-27 15:10:39
# 1  0b000064800a9d6f  2021-05-27 15:10:39
# 2  0b0000648023849a  2021-05-27 15:10:39
# 3  0b000064803ad512  2021-05-27 15:10:39
# 4  0b00006480409eac  2021-05-27 15:10:39

# %%
# test with flatfile AND a databawe
downloader.gather_headers("documents", params={"filter[agencyId]": "EPA",
                                                "filter[postedDate][ge]": "2019-01-01",
                                                "filter[postedDate][le]": "2019-06-30",},
                         db_filename="testdb2.db",
                         csv_filename="documents_test.csv")
# Out:
# Found 8038 documents...
#
# Enter outer loop (0 documents collected)...
#     250 documents retrieved
#     500 documents retrieved
#     750 documents retrieved
#     1000 documents retrieved
#     1250 documents retrieved
#     1500 documents retrieved
#     1750 documents retrieved
#     2000 documents retrieved
#     2250 documents retrieved
#     2500 documents retrieved
#     2750 documents retrieved
#     3000 documents retrieved
#     3250 documents retrieved
#     3500 documents retrieved
#     3750 documents retrieved
#     4000 documents retrieved
#     4250 documents retrieved
#     4500 documents retrieved
#     4750 documents retrieved
#     5000 documents retrieved
# 2021-05-27 11:14:23: Inserting 5000 records into database...
# 2021-05-27 11:14:24: Writing 5000 records to documents_test.csv...Done
#
# Enter outer loop (5000 documents collected)...
#     5250 documents retrieved
#     5500 documents retrieved
#     5750 documents retrieved
#     6000 documents retrieved
#     6250 documents retrieved
# (Requests left: 400)
#     6500 documents retrieved
#     6750 documents retrieved
#     7000 documents retrieved
#     7250 documents retrieved
#     7500 documents retrieved
#     7750 documents retrieved
#     8000 documents retrieved
#     8039 documents retrieved
# 2021-05-27 11:14:35: Inserting 3039 records into database...
# 2021-05-27 11:14:35: Writing 3039 records to documents_test.csv...Done
# 2021-05-27 11:14:35: Removing any duplicates in the CSV...
# 2021-05-27 11:14:35: Done. Removed 1 duplicate rows from documents_test.csv.
# 2021-05-27 11:14:35: Finished: approximately 8039 documents collected

# %% [markdown]
# ## comments

# %%
# get count comments header response
downloader.get_items_count("comments", params={"filter[agencyId]": "EPA",
                                                "filter[postedDate][ge]": "2019-01-01",
                                                "filter[postedDate][le]": "2019-03-30",})
# Out:
# 6152

# %%
downloader.gather_headers("comments", params={"filter[agencyId]": "EPA",
                                                "filter[postedDate][ge]": "2019-01-01",
                                                "filter[postedDate][le]": "2019-03-30",},
                          db_filename="testdb.db")
# Out:
# Found 6152 comments...
#
# Enter outer loop (0 comments collected)...
#     250 comments retrieved
#     500 comments retrieved
#     750 comments retrieved
#     1000 comments retrieved
#     1250 comments retrieved
#     1500 comments retrieved
#     1750 comments retrieved
#     2000 comments retrieved
#     2250 comments retrieved
#     2500 comments retrieved
#     2750 comments retrieved
#     3000 comments retrieved
#     3250 comments retrieved
#     3500 comments retrieved
#     3750 comments retrieved
#     4000 comments retrieved
#     4250 comments retrieved
#     4500 comments retrieved
#     4750 comments retrieved
#     5000 comments retrieved
# 2021-05-27 11:15:00: Inserting 5000 records into database...
#
# Enter outer loop (5000 comments collected)...
#     5250 comments retrieved
#     5500 comments retrieved
#     5750 comments retrieved
#     6000 comments retrieved
#     6153 comments retrieved
# 2021-05-27 11:15:05: Inserting 1153 records into database...
# 2021-05-27 11:15:06: Finished: approximately 6153 comments collected

# %%
with sqlite3.connect("testdb.db") as conn:
    x = pd.read_sql_query('select count(*) from comments_header', conn)
x
# Out:
#    count(*)
# 0      6152

# %%
with sqlite3.connect("testdb.db") as conn:
    x = pd.read_sql_query('select * from comments_header limit 10', conn)
x
# Out:
#                     commentId agencyId       documentType  \
# 0  EPA-R02-OAR-2017-0094-0011      EPA  Public Submission
# 1  EPA-R02-OAR-2017-0094-0012      EPA  Public Submission
# 2  EPA-R04-OAR-2018-0544-0004      EPA  Public Submission
# 3  EPA-R04-OAR-2018-0544-0003      EPA  Public Submission
# 4  EPA-R05-OAR-2017-0741-0004      EPA  Public Submission
# 5  EPA-R05-OAR-2018-0384-0003      EPA  Public Submission
# 6  EPA-R05-OAR-2018-0393-0003      EPA  Public Submission
# 7  EPA-R05-OAR-2018-0393-0004      EPA  Public Submission
# 8  EPA-R06-OAR-2015-0189-0281      EPA  Public Submission
# 9  EPA-R06-OAR-2015-0189-0280      EPA  Public Submission
#
#        lastModifiedDate          objectId            postedDate  \
# 0  2019-01-29T01:34:00Z  09000064839dddc8  2019-01-28T05:00:00Z
# 1  2019-01-29T01:34:20Z  09000064839e1ba3  2019-01-28T05:00:00Z
# 2  2019-01-29T01:34:38Z  09000064839e6930  2019-01-28T05:00:00Z
# 3  2019-01-29T01:34:56Z  09000064839e4021  2019-01-28T05:00:00Z
# 4  2019-01-29T01:35:15Z  090000648399264b  2019-01-28T05:00:00Z
# 5  2019-01-29T01:35:32Z  090000648399f9bc  2019-01-28T05:00:00Z
# 6  2019-01-29T01:35:52Z  09000064839c55ea  2019-01-28T05:00:00Z
# 7  2019-01-29T01:36:10Z  09000064839e6a58  2019-01-28T05:00:00Z
# 8  2019-01-29T01:36:30Z  09000064839d23bf  2019-01-28T05:00:00Z
# 9  2019-01-29T01:36:50Z  09000064839ce2d1  2019-01-28T05:00:00Z
#
#                                                title  withdrawn  \
# 0              Comment on EPA-R02-OAR-2017-0094-0001          0
# 1              Comment on EPA-R02-OAR-2017-0094-0001          0
# 2              Comment on EPA-R04-OAR-2018-0544-0001          0
# 3              Comment on EPA-R04-OAR-2018-0544-0001          0
# 4  Comment 1 on the Proposed approval of the Mich...          0
# 5  Comment 1 on Proposed Approval of Ohio Particu...          0
# 6  Public Comment 1 on the Proposed approval of t...          0
# 7  Public Comment 2 on the Proposed approval of t...          0
# 8  AR020.0281 Arkansas Affordable Energy Coalitio...          0
# 9  AR020.0280 Entergy Arkansas, LLC, Entergy Miss...          0
#
#                sqltime
# 0  2021-05-27 15:15:00
# 1  2021-05-27 15:15:00
# 2  2021-05-27 15:15:00
# 3  2021-05-27 15:15:00
# 4  2021-05-27 15:15:00
# 5  2021-05-27 15:15:00
# 6  2021-05-27 15:15:00
# 7  2021-05-27 15:15:00
# 8  2021-05-27 15:15:00
# 9  2021-05-27 15:15:00

# %%
# do document_header and docket_header still exist?
with sqlite3.connect("testdb.db") as conn:
    print(pd.read_sql_query('select count(*) from documents_header', conn))
    print(pd.read_sql_query('select count(*) from dockets_header', conn))
# Out:
#    count(*)
# 0      8038
#    count(*)
# 0     18041

# %%
# test with flatfile
downloader.gather_headers("comments", params={"filter[agencyId]": "EPA",
                                                "filter[postedDate][ge]": "2019-01-01",
                                                "filter[postedDate][le]": "2019-03-30",},
                         csv_filename="comments_test.csv")
# Out:
# Found 6152 comments...
#
# Enter outer loop (0 comments collected)...
#     250 comments retrieved
#     500 comments retrieved
#     750 comments retrieved
#     1000 comments retrieved
#     1250 comments retrieved
#     1500 comments retrieved
#     1750 comments retrieved
#     2000 comments retrieved
#     2250 comments retrieved
#     2500 comments retrieved
#     2750 comments retrieved
#     3000 comments retrieved
#     3250 comments retrieved
#     3500 comments retrieved
#     3750 comments retrieved
#     4000 comments retrieved
#     4250 comments retrieved
#     4500 comments retrieved
#     4750 comments retrieved
#     5000 comments retrieved
# 2021-05-27 11:15:29: Writing 5000 records to comments_test.csv...Done
#
# Enter outer loop (5000 comments collected)...
#     5250 comments retrieved
#     5500 comments retrieved
#     5750 comments retrieved
#     6000 comments retrieved
#     6153 comments retrieved
# 2021-05-27 11:15:34: Writing 1153 records to comments_test.csv...Done
# 2021-05-27 11:15:34: Removing any duplicates in the CSV...
# 2021-05-27 11:15:35: Done. Removed 1 duplicate rows from comments_test.csv.
# 2021-05-27 11:15:35: Finished: approximately 6153 comments collected

# %% [markdown]
# ### without trailing s

# %%
# test with new database
downloader.gather_headers("comment", params={"filter[agencyId]": "EPA",
                                                "filter[postedDate][ge]": "2019-01-01",
                                                "filter[postedDate][le]": "2019-03-30",},
                         db_filename="comments/comments.db")
# Out:
# Found 6152 comments...
#
# Enter outer loop (0 comments collected)...
#     250 comments retrieved
#     500 comments retrieved
#     750 comments retrieved
#     1000 comments retrieved
#     1250 comments retrieved
#     1500 comments retrieved
#     1750 comments retrieved
#     2000 comments retrieved
#     2250 comments retrieved
#     2500 comments retrieved
#     2750 comments retrieved
#     3000 comments retrieved
#     3250 comments retrieved
#     3500 comments retrieved
#     3750 comments retrieved
#     4000 comments retrieved
#     4250 comments retrieved
#     4500 comments retrieved
#     4750 comments retrieved
#     5000 comments retrieved
# 2021-05-27 11:15:58: Inserting 5000 records into database...
#
# Enter outer loop (5000 comments collected)...
#     5250 comments retrieved
#     5500 comments retrieved
#     5750 comments retrieved
#     6000 comments retrieved
#     6153 comments retrieved
# 2021-05-27 11:16:03: Inserting 1153 records into database...
# 2021-05-27 11:16:03: Finished: approximately 6153 comments collected

# %%
with sqlite3.connect("comments/comments.db") as conn:
    print(pd.read_sql_query('select count(*) from comments_header', conn))
# Out:
#    count(*)
# 0      6152

# %% [markdown]
# # test gather_details

# %% [markdown]
# # dockets

# %%
with sqlite3.connect("testdb.db") as conn:
    docket_ids = pd.read_sql_query('select docketId from dockets_header limit 25', conn)['docketId'].values

# %%
downloader.gather_details("dockets", docket_ids, db_filename="testdb.db", insert_every_n_rows=10)
# Out:
# 2021-05-27 11:16:03: Gathering details for 25 dockets...
# 2021-05-27 11:16:05: Inserting 10 records into database...
# (Requests left: 300)
# (Requests left: 300)
# 2021-05-27 11:16:07: Inserting 10 records into database...
# 2021-05-27 11:16:08: Inserting 5 records into database...
# 2021-05-27 11:16:09: Finished: 25 dockets collected

# %%
with sqlite3.connect("testdb.db") as conn:
    x = pd.read_sql_query('select count(*) from dockets_detail', conn)
x
# Out:
#    count(*)
# 0        25

# %%
with sqlite3.connect("testdb.db") as conn:
    x = pd.read_sql_query('select * from dockets_detail limit 5', conn)
x
# Out:
#               docketId agencyId category  \
# 0  EPA-HQ-OA-2002-0001      EPA     None
# 1  EPA-HQ-OA-2003-0001      EPA     None
# 2  EPA-HQ-OA-2003-0003      EPA     None
# 3  EPA-HQ-OA-2003-0005      EPA     None
# 4  EPA-HQ-OA-2003-0006      EPA     None
#
#                                           dkAbstract     docketType  \
# 0  Points of Contact: Kimberly Patrick 202-566-26...     Rulemaking
# 1  Contact:  Bob Sachs\r\nUSEPA-West, 1808T\r\n12...  Nonrulemaking
# 2  Contact: Yasmin Yorker\r\nTeam VI Team Leader\...  Nonrulemaking
# 3  Patricia Bonner, 1200 Pennsylvania Ave. NW, Wa...  Nonrulemaking
# 4  Point of Contact: Marc Olender,  Telephone: (2...  Nonrulemaking
#
#   effectiveDate field1 field2 generic keywords  ...          objectId  \
# 0          None   None   None   HQ-OA     None  ...  0b000064800ac06d
# 1          None   None   None   HQ-OA     None  ...  0b000064800ad281
# 2          None   None   None   HQ-OA     None  ...  0b000064800ad3b9
# 3          None   None   None   HQ-OA     None  ...  0b000064800ad4b9
# 4          None   None   None   HQ-OA     None  ...  0b000064800ad6e3
#
#   organization petitionNbr program           rin  \
# 0  EC-2000-003        None    None  Not Assigned
# 1  ICR 1949.02        None    None          None
# 2  ICR 0275.08        None    None          None
# 3         None        None    None          None
# 4         None        None    None          None
#
#                       shortTitle subType subType2  \
# 0                           None    None     None
# 1                           None    None     None
# 2                           None    None     None
# 3  EPA Public Involvement Policy    None     None
# 4                           None    None     None
#
#                                                title              sqltime
# 0  Participation by Small, Minority and Women's B...  2021-05-27 15:16:05
# 1  The National Environmental Performance Track P...  2021-05-27 15:16:05
# 2  Preaward Compliance Review Report for All Appl...  2021-05-27 15:16:05
# 3                      EPA Public Involvement Policy  2021-05-27 15:16:05
# 4  State Access / Input to the EPA Innovation Cat...  2021-05-27 15:16:05
#
# [5 rows x 22 columns]

# %%
# test with flatfile
downloader.gather_details("dockets", docket_ids, csv_filename="dockets_test_detail.csv", insert_every_n_rows=10)
# Out:
# 2021-05-27 11:16:09: Gathering details for 25 dockets...
# 2021-05-27 11:16:11: Writing 10 records to dockets_test_detail.csv...Done
# 2021-05-27 11:16:13: Writing 10 records to dockets_test_detail.csv...Done
# 2021-05-27 11:16:14: Writing 5 records to dockets_test_detail.csv...Done
# 2021-05-27 11:16:14: Finished: 25 dockets collected

# %%
# test with flatfile, to new directory
downloader.gather_details("dockets", docket_ids, csv_filename="blah2/dockets_test_detail.csv", insert_every_n_rows=10)
# Out:
# 2021-05-27 11:16:14: Gathering details for 25 dockets...
# 2021-05-27 11:16:16: Writing 10 records to blah2/dockets_test_detail.csv...Done
# 2021-05-27 11:16:18: Writing 10 records to blah2/dockets_test_detail.csv...Done
# 2021-05-27 11:16:19: Writing 5 records to blah2/dockets_test_detail.csv...Done
# 2021-05-27 11:16:19: Finished: 25 dockets collected

# %% [markdown]
# ## documents

# %%
with sqlite3.connect("testdb.db") as conn:
    document_ids = pd.read_sql_query('select documentId from documents_header limit 25', conn)['documentId'].values

# %%
downloader.gather_details("documents", document_ids, db_filename="testdb.db", insert_every_n_rows=10)
# Out:
# 2021-05-27 11:16:19: Gathering details for 25 documents...
# 2021-05-27 11:16:21: Inserting 10 records into database...
# 2021-05-27 11:16:23: Inserting 10 records into database...
# 2021-05-27 11:16:24: Inserting 5 records into database...
# 2021-05-27 11:16:24: Finished: 25 documents collected

# %%
with sqlite3.connect("testdb.db") as conn:
    x = pd.read_sql_query('select count(*) from documents_detail', conn)
x
# Out:
#    count(*)
# 0        25

# %%
with sqlite3.connect("testdb.db") as conn:
    x = pd.read_sql_query('select * from documents_detail limit 5', conn)
x
# Out:
#                   documentId additionalRins agencyId  allowLateComments  \
# 0   EPA-HQ-OA-2015-0553-0010           None      EPA                  0
# 1   EPA-HQ-OA-2015-0553-0011           None      EPA                  0
# 2   EPA-HQ-OA-2015-0553-0012           None      EPA                  0
# 3  EPA-HQ-OAR-2001-0012-0478           None      EPA                  0
# 4  EPA-HQ-OAR-2001-0012-0479           None      EPA                  0
#
#              authorDate                 authors category cfrPart  city  \
# 0                  None                    None     None    None  None
# 1                  None                    None     None    None  None
# 2                  None                    None     None    None  None
# 3  2018-05-09T04:00:00Z        Tom Peake US EPA     None    None  None
# 4  2018-08-02T04:00:00Z  Lee Ann B. Veal US EPA     None    None  None
#
#   comment  ... subject submitterRep submitterRepCityState  \
# 0    None  ...    None         None                  None
# 1    None  ...    None         None                  None
# 2    None  ...    None         None                  None
# 3    None  ...    None         None                  None
# 4    None  ...    None         None                  None
#
#                                 subtype  \
# 0  Information Collection Request (ICR)
# 1              ICR Supporting Statement
# 2                           Application
# 3                                Letter
# 4                                Letter
#
#                                                title topics    trackingNbr  \
# 0  Agency Information Collection Activities; Prop...   None           None
# 1  2524ss02 - CEQ-EPA Presidential Innovation Awa...   None  1k3-98sh-y2n0
# 2  2524ss02 - Attachment A - CEQ-EPA Presidential...   None  1k3-98sh-bfx0
# 3  ORNL CCP (CH & RH) Continued Compliance Letter...   None  1k3-98r5-rp5l
# 4  2017 Waste Isolation Pilot Plant (WIPP) Site (...   None  1k3-98r5-eile
#
#   withdrawn   zip              sqltime
# 0         0  None  2021-05-27 15:16:21
# 1         0  None  2021-05-27 15:16:21
# 2         0  None  2021-05-27 15:16:21
# 3         0  None  2021-05-27 15:16:21
# 4         0  None  2021-05-27 15:16:21
#
# [5 rows x 59 columns]

# %%
# test with flatfile
downloader.gather_details("documents", document_ids, csv_filename="documents_test_detail.csv", insert_every_n_rows=10)
# Out:
# 2021-05-27 11:16:24: Gathering details for 25 documents...
# 2021-05-27 11:16:26: Writing 10 records to documents_test_detail.csv...Done
# (Requests left: 200)
# 2021-05-27 11:16:28: Writing 10 records to documents_test_detail.csv...Done
# 2021-05-27 11:16:29: Writing 5 records to documents_test_detail.csv...Done
# 2021-05-27 11:16:29: Finished: 25 documents collected

# %% [markdown]
# ## comments

# %%
with sqlite3.connect("testdb.db") as conn:
    comment_ids = pd.read_sql_query('select commentId from comments_header limit 25', conn)['commentId'].values

# %%
downloader.gather_details("comments", comment_ids, "testdb.db", insert_every_n_rows=10)
# Out:
# 2021-05-27 11:16:29: Gathering details for 25 comments...
# 2021-05-27 11:16:31: Inserting 10 records into database...
# 2021-05-27 11:16:33: Inserting 10 records into database...
# 2021-05-27 11:16:34: Inserting 5 records into database...
# 2021-05-27 11:16:35: Finished: 25 comments collected

# %%
with sqlite3.connect("testdb.db") as conn:
    print(pd.read_sql_query('select count(*) from comments_detail', conn))
# Out:
#    count(*)
# 0        25

# %%
pd.read_sql_query('select * from comments_detail limit 5', conn)
# Out:
#                    commentId agencyId category  city  \
# 0   EPA-HQ-OA-2007-0677-0007      EPA     None  None
# 1   EPA-HQ-OA-2018-0259-9301      EPA     None  None
# 2  EPA-HQ-OAR-2002-0070-0007      EPA     None  None
# 3  EPA-HQ-OAR-2002-0070-0008      EPA     None  None
# 4  EPA-HQ-OAR-2002-0070-0010      EPA     None  None
#
#                                              comment         commentOn  \
# 0  This method of assessment seems to be very tho...  0900006480272c3d
# 1                                       See attached  090000648320bc9e
# 2                                       See attached  09000064837c4c7f
# 3                                       See attached  09000064837c4c7f
# 4                                       See attached  09000064837c4c7f
#
#          commentOnDocumentId country                         docAbstract  \
# 0   EPA-HQ-OA-2007-0677-0001    None                                None
# 1   EPA-HQ-OA-2018-0259-0001    None                                None
# 2  EPA-HQ-OAR-2002-0070-0003    None               Volkswagen of America
# 3  EPA-HQ-OAR-2002-0070-0003    None  Motor Vehicle Manufacturers Assoc.
# 4  EPA-HQ-OAR-2002-0070-0003    None           General Motors (FE-3419 )
#
#                docketId  ... restrictReasonType  stateProvinceRegion  \
# 0   EPA-HQ-OA-2007-0677  ...               None                 None
# 1   EPA-HQ-OA-2018-0259  ...               None                 None
# 2  EPA-HQ-OAR-2002-0070  ...               None                 None
# 3  EPA-HQ-OAR-2002-0070  ...               None                 None
# 4  EPA-HQ-OAR-2002-0070  ...               None                 None
#
#   submitterRep submitterRepCityState                       subtype  \
# 0         None                  None                Public Comment
# 1         None                  None                  Late Comment
# 2         None                  None  Company/Organization Comment
# 3         None                  None  Company/Organization Comment
# 4         None                  None  Company/Organization Comment
#
#                                                title    trackingNbr withdrawn  \
# 0                           Anonymous public comment  1k3-97sf-rtwm         0
# 1                     Comment submitted by A. Thomas  1k3-97yj-s62a         0
# 2  Comment submitted by Wolfgang Groth, Manager, ...  1k2-95xf-of9z         0
# 3  Comment submitted by Harry B. Weaver, Director...  1k2-95xf-gzw2         0
# 4  Comment submitted by T. M. Fisher, Director, A...  1k2-95xf-5c97         0
#
#     zip              sqltime
# 0  None  2021-05-27 15:16:31
# 1  None  2021-05-27 15:16:31
# 2  None  2021-05-27 15:16:31
# 3  None  2021-05-27 15:16:31
# 4  None  2021-05-27 15:16:31
#
# [5 rows x 40 columns]

# %%
# test with flatfile and database
downloader.gather_details("comments", comment_ids, db_filename="testdb.db", csv_filename="comments_test_detail.csv", insert_every_n_rows=10)
# Out:
# 2021-05-27 11:16:35: Gathering details for 25 comments...
# 2021-05-27 11:16:37: Inserting 10 records into database...
# 2021-05-27 11:16:37: Writing 10 records to comments_test_detail.csv...Done
# 2021-05-27 11:16:39: Inserting 10 records into database...
# 2021-05-27 11:16:39: Writing 10 records to comments_test_detail.csv...Done
# 2021-05-27 11:16:40: Inserting 5 records into database...
# 2021-05-27 11:16:40: Writing 5 records to comments_test_detail.csv...Done
# 2021-05-27 11:16:40: Finished: 25 comments collected

# %%
# shouldn't have more than 25 (unique constraint)
with sqlite3.connect("testdb.db") as conn:
    print(pd.read_sql_query('select count(*) from comments_detail', conn))
# Out:
#    count(*)
# 0        25

# %% [markdown]
# ### test without trailing s

# %%
downloader.gather_details("comment", comment_ids, "testdb2.db", insert_every_n_rows=10)
# Out:
# 2021-05-27 11:16:40: Gathering details for 25 comments...
# 2021-05-27 11:16:42: Inserting 10 records into database...
# 2021-05-27 11:16:44: Inserting 10 records into database...
# 2021-05-27 11:16:45: Inserting 5 records into database...
# 2021-05-27 11:16:45: Finished: 25 comments collected

# %% [markdown]
# # test duplicates on server
#
# Should skip any that have duplicates on server

# %%
with sqlite3.connect("testdb.db") as conn:
    comment_ids = pd.read_sql_query('select commentId from comments_header limit 25', conn)['commentId'].values

# %%
downloader.gather_details("comments", [*comment_ids[1:3], 'NRCS-2009-0004-0003', *comment_ids[4:6]], csv_filename="comments_test_detail2.csv", insert_every_n_rows=10)
# Out:
# 2021-05-27 11:16:45: Gathering details for 5 comments...
# ****Duplicate entries on server. Skipping.
# Incorrect result size: expected 1, actual 2
# Skipping for NRCS-2009-0004-0003
#
# 2021-05-27 11:16:46: Writing 4 records to comments_test_detail2.csv...Done
# 2021-05-27 11:16:46: Finished: 4 comments collected

# %%
# test without skipping duplicates
#downloader.gather_details("comments", [*comment_ids[1:3], 'NRCS-2009-0004-0003', *comment_ids[4:6]], csv_filename="comments_test_detail2.csv", 
#                          insert_every_n_rows=10, skip_duplicates=False)

# %% [markdown]
# # Test get_ids_from_csv

# %%
x = downloader.get_ids_from_csv("dockets_test.csv", data_type="dockets")
x[:10]
# Out:
# ['EPA-R06-OAR-2005-TX-0034',
#  'EPA-R06-OAR-2004-TX-0004',
#  'EPA-R10-OAR-2007-0411',
#  'EPA-R10-OAR-2008-0130',
#  'EPA-R03-RCRA-2008-0256',
#  'EPA-R09-OAR-2007-1112',
#  'EPA-R09-OAR-2008-0406',
#  'EPA-R09-OAR-2007-0951',
#  'EPA-R09-OAR-2007-0964',
#  'EPA-R06-OAR-2007-1064']

# %%
len(x)
# Out:
# 18041

# %%
x = downloader.get_ids_from_csv("dockets_test.csv", data_type="dockets", unique=True)
len(x)
# Out:
# 18041

# %% [markdown]
# # gather_comments_by_document

# %%
api_key = getpass.getpass("Enter API key")
downloader = CommentsDownloader(api_key)
downloader.get_requests_remaining()
# Out:
# 541

# %%
downloader.gather_comments_by_document("FDA-2009-N-0501-0012", db_filename="testdb.db")
# Out:
# 2021-05-27 11:22:55: Getting objectId for document FDA-2009-N-0501-0012...Got it (09000064847f0822)
# 2021-05-27 11:22:55: Getting comment headers associated with document FDA-2009-N-0501-0012...
#
# Found 10 comments...
# 2021-05-27 11:22:56: Inserting 10 records into database...
# 2021-05-27 11:22:56: Writing 10 records to comment_headers_112255.csv...Done
# 2021-05-27 11:22:56: Removing any duplicates in the CSV...
# 2021-05-27 11:22:56: Done. Removed 0 duplicate rows from comment_headers_112255.csv.
# 2021-05-27 11:22:56: Finished: approximately 10 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 11:22:56: Getting comments associated with document FDA-2009-N-0501-0012...
#
# 2021-05-27 11:22:56: Gathering details for 10 comments...
# 2021-05-27 11:22:58: Inserting 10 records into database...
# 2021-05-27 11:22:58: Finished: 10 comments collected
#
# Done getting all 10 comments for document FDA-2009-N-0501-0012----------------

# %%
conn = sqlite3.connect("testdb.db")
pd.read_sql_query("select * from comments_detail where commentOnDocumentId='FDA-2009-N-0501-0012'", conn)
# Out:
#               commentId agencyId             category  city  \
# 0  FDA-2009-N-0501-0018      FDA                 None  None
# 1  FDA-2009-N-0501-0017      FDA                 None  None
# 2  FDA-2009-N-0501-0019      FDA                 None  None
# 3  FDA-2009-N-0501-0013      FDA  Individual Consumer  None
# 4  FDA-2009-N-0501-0020      FDA                 None  None
# 5  FDA-2009-N-0501-0014      FDA                 None  None
# 6  FDA-2009-N-0501-0015      FDA                 None  None
# 7  FDA-2009-N-0501-0021      FDA                 None  None
# 8  FDA-2009-N-0501-0016      FDA                 None  None
# 9  FDA-2009-N-0501-0022      FDA                 None  None
#
#                                              comment         commentOn  \
# 0                           I OPPOSE this regulation  09000064847f0822
# 1                           I OPPOSE this regulation  09000064847f0822
# 2                           I OPPOSE this regulation  09000064847f0822
# 3  In her role as WH Chief Propagandist, Kayleigh...  09000064847f0822
# 4                           I OPPOSE this regulation  09000064847f0822
# 5                          I oppose this regulation.  09000064847f0822
# 6                         I support this regulation.  09000064847f0822
# 7                           I OPPOSE this regulation  09000064847f0822
# 8                                    I support this.  09000064847f0822
# 9  Thanks to Dr. Stephen Hahn&#39;s politicizatio...  09000064847f0822
#
#     commentOnDocumentId        country docAbstract         docketId  ...  \
# 0  FDA-2009-N-0501-0012           None        None  FDA-2009-N-0501  ...
# 1  FDA-2009-N-0501-0012           None        None  FDA-2009-N-0501  ...
# 2  FDA-2009-N-0501-0012           None        None  FDA-2009-N-0501  ...
# 3  FDA-2009-N-0501-0012           None        None  FDA-2009-N-0501  ...
# 4  FDA-2009-N-0501-0012           None        None  FDA-2009-N-0501  ...
# 5  FDA-2009-N-0501-0012  United States        None  FDA-2009-N-0501  ...
# 6  FDA-2009-N-0501-0012  United States        None  FDA-2009-N-0501  ...
# 7  FDA-2009-N-0501-0012           None        None  FDA-2009-N-0501  ...
# 8  FDA-2009-N-0501-0012  United States        None  FDA-2009-N-0501  ...
# 9  FDA-2009-N-0501-0012           None        None  FDA-2009-N-0501  ...
#
#   restrictReasonType  stateProvinceRegion submitterRep submitterRepCityState  \
# 0               None                 None         None                  None
# 1               None                 None         None                  None
# 2               None                 None         None                  None
# 3               None                 None         None                  None
# 4               None                 None         None                  None
# 5               None                   DC         None                  None
# 6               None                   DC         None                  None
# 7               None                 None         None                  None
# 8               None                   DC         None                  None
# 9               None                 None         None                  None
#
#                            subtype                        title  \
# 0  Electronic Regulation from Form      Comment from David Test
# 1  Electronic Regulation from Form      Comment from David Test
# 2  Electronic Regulation from Form      Comment from David Test
# 3  Electronic Regulation from Form       Comment from Anonymous
# 4  Electronic Regulation from Form      Comment from David Test
# 5  Electronic Regulation from Form  Comment from David Ranshous
# 6  Electronic Regulation from Form  Comment from David Ranshous
# 7  Electronic Regulation from Form      Comment from David Test
# 8  Electronic Regulation from Form  Comment from David Ranshous
# 9  Electronic Regulation from Form       Comment from Anonymous
#
#      trackingNbr withdrawn   zip              sqltime
# 0  kex-2hk4-zgxx         0  None  2021-05-27 15:19:48
# 1  kex-1zhg-cyf0         0  None  2021-05-27 15:19:48
# 2  kex-2jsz-p1mn         0  None  2021-05-27 15:19:48
# 3  kew-qi1w-4tk6         0  None  2021-05-27 15:19:48
# 4  kex-2sr3-gqrc         0  None  2021-05-27 15:19:48
# 5  kew-ud0g-udb3         0  None  2021-05-27 15:19:48
# 6  kew-w3m1-idgm         0  None  2021-05-27 15:19:48
# 7  kex-2tsr-8w58         0  None  2021-05-27 15:19:48
# 8  kex-0fv9-msin         0  None  2021-05-27 15:19:48
# 9  kex-etes-rpe6         0  None  2021-05-27 15:19:48
#
# [10 rows x 40 columns]

# %% [markdown]
# ## Add comments from another document. Also write to flat file

# %%
downloader.gather_comments_by_document("EERE-2019-BT-STD-0036-0001", db_filename="testdb.db", csv_filename="mydocument/mydata.csv")
# Out:
# 2021-05-27 11:23:09: Getting objectId for document EERE-2019-BT-STD-0036-0001...Got it (0900006484a7a258)
# 2021-05-27 11:23:10: Getting comment headers associated with document EERE-2019-BT-STD-0036-0001...
#
# Found 17 comments...
# 2021-05-27 11:23:10: Inserting 17 records into database...
# 2021-05-27 11:23:10: Writing 17 records to comment_headers_112310.csv...Done
# 2021-05-27 11:23:10: Removing any duplicates in the CSV...
# 2021-05-27 11:23:10: Done. Removed 0 duplicate rows from comment_headers_112310.csv.
# 2021-05-27 11:23:10: Finished: approximately 17 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 11:23:10: Getting comments associated with document EERE-2019-BT-STD-0036-0001...
#
# 2021-05-27 11:23:10: Gathering details for 17 comments...
# 2021-05-27 11:23:14: Inserting 17 records into database...
# 2021-05-27 11:23:14: Writing 17 records to mydocket/mydata.csv...Done
# 2021-05-27 11:23:14: Finished: 17 comments collected
#
# Done getting all 17 comments for document EERE-2019-BT-STD-0036-0001----------------

# %%
pd.read_sql_query("select * from comments_detail", conn)
# Out:
#                      commentId agencyId                     category  city  \
# 0     EPA-HQ-OA-2007-0677-0007      EPA                         None  None
# 1     EPA-HQ-OA-2018-0259-9301      EPA                         None  None
# 2    EPA-HQ-OAR-2002-0070-0007      EPA                         None  None
# 3    EPA-HQ-OAR-2002-0070-0008      EPA                         None  None
# 4    EPA-HQ-OAR-2002-0070-0010      EPA                         None  None
# ..                         ...      ...                          ...   ...
# 228       FDA-2021-N-0270-0042      FDA             Academia - E0007  None
# 229       FDA-2021-N-0270-0058      FDA          Individual Consumer  None
# 230       FDA-2021-N-0270-0023      FDA                         None  None
# 231       FDA-2021-N-0270-0013      FDA                         None  None
# 232       FDA-2021-N-0270-0048      FDA  Health Professional - A0007  None
#
#                                                comment         commentOn  \
# 0    This method of assessment seems to be very tho...  0900006480272c3d
# 1                                         See attached  090000648320bc9e
# 2                                         See attached  09000064837c4c7f
# 3                                         See attached  09000064837c4c7f
# 4                                         See attached  09000064837c4c7f
# ..                                                 ...               ...
# 228  Developing type 1 diabetes before age 10 is as...  0900006484a930da
# 229  What difference does delaying T1D onset 2+ yea...  0900006484a930da
# 230                               See attached file(s)  0900006484a930da
# 231  I&#39;m writing in support of FDA approval for...  0900006484a930da
# 232  Being diagnosed with Type 1 DM and living with...  0900006484a930da
#
#            commentOnDocumentId        country  \
# 0     EPA-HQ-OA-2007-0677-0001           None
# 1     EPA-HQ-OA-2018-0259-0001           None
# 2    EPA-HQ-OAR-2002-0070-0003           None
# 3    EPA-HQ-OAR-2002-0070-0003           None
# 4    EPA-HQ-OAR-2002-0070-0003           None
# ..                         ...            ...
# 228       FDA-2021-N-0270-0001        Germany
# 229       FDA-2021-N-0270-0001  United States
# 230       FDA-2021-N-0270-0001  United States
# 231       FDA-2021-N-0270-0001  United States
# 232       FDA-2021-N-0270-0001  United States
#
#                             docAbstract              docketId  ...  \
# 0                                  None   EPA-HQ-OA-2007-0677  ...
# 1                                  None   EPA-HQ-OA-2018-0259  ...
# 2                 Volkswagen of America  EPA-HQ-OAR-2002-0070  ...
# 3    Motor Vehicle Manufacturers Assoc.  EPA-HQ-OAR-2002-0070  ...
# 4             General Motors (FE-3419 )  EPA-HQ-OAR-2002-0070  ...
# ..                                  ...                   ...  ...
# 228                                None       FDA-2021-N-0270  ...
# 229                                None       FDA-2021-N-0270  ...
# 230                                None       FDA-2021-N-0270  ...
# 231                                None       FDA-2021-N-0270  ...
# 232                                None       FDA-2021-N-0270  ...
#
#     restrictReasonType  stateProvinceRegion submitterRep  \
# 0                 None                 None         None
# 1                 None                 None         None
# 2                 None                 None         None
# 3                 None                 None         None
# 4                 None                 None         None
# ..                 ...                  ...          ...
# 228               None                 None         None
# 229               None                 None         None
# 230               None                   CA         None
# 231               None                   NJ         None
# 232               None                   MI         None
#
#     submitterRepCityState                          subtype  \
# 0                    None                   Public Comment
# 1                    None                     Late Comment
# 2                    None     Company/Organization Comment
# 3                    None     Company/Organization Comment
# 4                    None     Company/Organization Comment
# ..                    ...                              ...
# 228                  None  Electronic Regulation from Form
# 229                  None  Electronic Regulation from Form
# 230                  None  Electronic Regulation from Form
# 231                  None  Electronic Regulation from Form
# 232                  None  Electronic Regulation from Form
#
#                                                  title    trackingNbr  \
# 0                             Anonymous public comment  1k3-97sf-rtwm
# 1                       Comment submitted by A. Thomas  1k3-97yj-s62a
# 2    Comment submitted by Wolfgang Groth, Manager, ...  1k2-95xf-of9z
# 3    Comment submitted by Harry B. Weaver, Director...  1k2-95xf-gzw2
# 4    Comment submitted by T. M. Fisher, Director, A...  1k2-95xf-5c97
# ..                                                 ...            ...
# 228     Comment from Peod. Dr. Anette-Gabriele Ziegler  kod-2fm0-ny6e
# 229                             Comment from A Sweeney  kok-j8yx-29cc
# 230                          Comment from Annie Mavian  ko4-suvf-s7ip
# 231                         Comment from Michael Walsh  ko2-x3i4-rf6e
# 232                     Comment from Carol Ciaramitaro  kok-dmt9-f1oj
#
#     withdrawn   zip              sqltime
# 0           0  None  2021-05-27 15:16:31
# 1           0  None  2021-05-27 15:16:31
# 2           0  None  2021-05-27 15:16:31
# 3           0  None  2021-05-27 15:16:31
# 4           0  None  2021-05-27 15:16:31
# ..        ...   ...                  ...
# 228         0  None  2021-05-27 15:21:14
# 229         0  None  2021-05-27 15:21:14
# 230         0  None  2021-05-27 15:21:14
# 231         0  None  2021-05-27 15:21:14
# 232         0  None  2021-05-27 15:21:14
#
# [233 rows x 40 columns]

# %% [markdown]
# ## Write to flatfile only

# %%
downloader.gather_comments_by_document("FDA-2021-N-0270-0001", csv_filename="mydata.csv")
# Out:
# 2021-05-27 11:27:53: Getting objectId for document FDA-2021-N-0270-0001...Got it (0900006484a930da)
# 2021-05-27 11:27:53: Getting comment headers associated with document FDA-2021-N-0270-0001...
#
# Found 181 comments...
# 2021-05-27 11:27:54: Writing 181 records to comment_headers_112753.csv...Done
# 2021-05-27 11:27:54: Removing any duplicates in the CSV...
# 2021-05-27 11:27:54: Done. Removed 0 duplicate rows from comment_headers_112753.csv.
# 2021-05-27 11:27:54: Finished: approximately 181 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 11:27:54: Getting comments associated with document FDA-2021-N-0270-0001...
#
# 2021-05-27 11:27:54: Gathering details for 181 comments...
# 2021-05-27 11:28:30: Writing 181 records to mydata.csv...Done
# 2021-05-27 11:28:30: Finished: 181 comments collected
#
# Done getting all 181 comments for document FDA-2021-N-0270-0001----------------

# %% [markdown]
# ## write to a brand new database (create it automatically)

# %%
api_key = getpass.getpass("Enter API key")
downloader = CommentsDownloader(api_key)
downloader.get_requests_remaining()
# Out:
# 609

# %%
downloader.gather_comments_by_document("EERE-2019-BT-STD-0036-0001", db_filename="mydb.db")
# Out:
# 2021-05-27 11:28:57: Getting objectId for document EERE-2019-BT-STD-0036-0001...Got it (0900006484a7a258)
# 2021-05-27 11:28:57: Getting comment headers associated with document EERE-2019-BT-STD-0036-0001...
#
# Found 17 comments...
# 2021-05-27 11:28:58: Inserting 17 records into database...
# 2021-05-27 11:28:58: Writing 17 records to comment_headers_112857.csv...Done
# 2021-05-27 11:28:58: Removing any duplicates in the CSV...
# 2021-05-27 11:28:58: Done. Removed 0 duplicate rows from comment_headers_112857.csv.
# 2021-05-27 11:28:58: Finished: approximately 17 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 11:28:58: Getting comments associated with document EERE-2019-BT-STD-0036-0001...
#
# 2021-05-27 11:28:58: Gathering details for 17 comments...
# 2021-05-27 11:29:02: Inserting 17 records into database...
# 2021-05-27 11:29:02: Finished: 17 comments collected
#
# Done getting all 17 comments for document EERE-2019-BT-STD-0036-0001----------------

# %% [markdown]
# # gather_comments_by_docket

# %%
api_key = getpass.getpass("Enter API key")
downloader = CommentsDownloader(api_key)
downloader.get_requests_remaining()
# Out:
# 794

# %%
downloader.gather_comments_by_docket("FDA-2021-N-0270", db_filename="testdb.db", csv_filename="mydocket2/info.csv")
# Out:
# 2021-05-27 11:29:27: Getting documents associated with docket...
#
# Found 1 documents...
# 2021-05-27 11:29:27: Inserting 1 records into database...
# 2021-05-27 11:29:27: Writing 1 records to document_headers_112927.csv...Done
# 2021-05-27 11:29:27: Removing any duplicates in the CSV...
# 2021-05-27 11:29:27: Done. Removed 0 duplicate rows from document_headers_112927.csv.
# 2021-05-27 11:29:27: Finished: approximately 1 documents collected
#
# Done----------------
#
# ******************************
# 2021-05-27 11:29:28: Getting comments for document FDA-2021-N-0270-0001...
#
# 2021-05-27 11:29:28: Getting objectId for document FDA-2021-N-0270-0001...Got it (0900006484a930da)
# 2021-05-27 11:29:28: Getting comment headers associated with document FDA-2021-N-0270-0001...
#
# Found 181 comments...
# 2021-05-27 11:29:29: Inserting 181 records into database...
# 2021-05-27 11:29:29: Writing 181 records to comment_headers_112928.csv...Done
# 2021-05-27 11:29:29: Removing any duplicates in the CSV...
# 2021-05-27 11:29:29: Done. Removed 0 duplicate rows from comment_headers_112928.csv.
# 2021-05-27 11:29:29: Finished: approximately 181 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 11:29:29: Getting comments associated with document FDA-2021-N-0270-0001...
#
# 2021-05-27 11:29:29: Gathering details for 181 comments...
# (Requests left: 700)
# 2021-05-27 11:30:07: Inserting 181 records into database...
# 2021-05-27 11:30:07: Writing 181 records to mydocket2/info.csv...Done
# 2021-05-27 11:30:07: Finished: 181 comments collected
#
# Done getting all 181 comments for document FDA-2021-N-0270-0001----------------
#
# DONE retrieving all 181 comments from 1 document(s) for docket FDA-2021-N-0270----------------

# %%
conn = sqlite3.connect("testdb.db")
cur = conn.cursor()
cur.execute("select count(*) from comments_detail where docketId='FDA-2021-N-0270'").fetchone()[0]
# Out:
# 181

# %%
conn.close()

# %% [markdown]
# ## a docket with comments on multiple of its documents

# %%
# DOT-OST-2012-0147	 has 15 documents and 314 comments total.
downloader.gather_comments_by_docket("DOT-OST-2012-0147", db_filename="testdb.db", csv_filename="DOT-OST-2012-0147.csv")
# Out:
# 2021-05-27 11:30:50: Getting documents associated with docket...
#
# Found 15 documents...
# 2021-05-27 11:30:51: Inserting 15 records into database...
# 2021-05-27 11:30:51: Writing 15 records to document_headers_113050.csv...Done
# 2021-05-27 11:30:51: Removing any duplicates in the CSV...
# 2021-05-27 11:30:51: Done. Removed 0 duplicate rows from document_headers_113050.csv.
# 2021-05-27 11:30:51: Finished: approximately 15 documents collected
#
# Done----------------
#
# ******************************
# 2021-05-27 11:30:51: Getting comments for document DOT-OST-2012-0147-0005...
#
# 2021-05-27 11:30:51: Getting objectId for document DOT-OST-2012-0147-0005...Got it (0900006481110073)
# 2021-05-27 11:30:51: Getting comment headers associated with document DOT-OST-2012-0147-0005...
#
# Found 0 comments...
# 2021-05-27 11:30:51: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document DOT-OST-2012-0147-0005----------------
#
# ******************************
# 2021-05-27 11:30:51: Getting comments for document DOT-OST-2012-0147-0001...
#
# 2021-05-27 11:30:51: Getting objectId for document DOT-OST-2012-0147-0001...Got it (09000064810efebb)
# 2021-05-27 11:30:51: Getting comment headers associated with document DOT-OST-2012-0147-0001...
#
# Found 75 comments...
# 2021-05-27 11:30:53: Inserting 75 records into database...
# 2021-05-27 11:30:53: Writing 75 records to comment_headers_113051.csv...Done
# 2021-05-27 11:30:53: Removing any duplicates in the CSV...
# 2021-05-27 11:30:53: Done. Removed 0 duplicate rows from comment_headers_113051.csv.
# 2021-05-27 11:30:53: Finished: approximately 75 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 11:30:53: Getting comments associated with document DOT-OST-2012-0147-0001...
#
# 2021-05-27 11:30:53: Gathering details for 75 comments...
# (Requests left: 600)
# (Requests left: 600)
# 2021-05-27 11:31:08: Inserting 75 records into database...
# 2021-05-27 11:31:08: Writing 75 records to DOT-OST-2012-0147.csv...Done
# 2021-05-27 11:31:08: Finished: 75 comments collected
#
# Done getting all 75 comments for document DOT-OST-2012-0147-0001----------------
#
# ******************************
# 2021-05-27 11:31:08: Getting comments for document DOT-OST-2012-0147-0288...
#
# 2021-05-27 11:31:08: Getting objectId for document DOT-OST-2012-0147-0288...Got it (09000064814bb632)
# 2021-05-27 11:31:08: Getting comment headers associated with document DOT-OST-2012-0147-0288...
#
# Found 0 comments...
# 2021-05-27 11:31:09: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document DOT-OST-2012-0147-0288----------------
#
# ******************************
# 2021-05-27 11:31:09: Getting comments for document DOT-OST-2012-0147-0319...
#
# 2021-05-27 11:31:09: Getting objectId for document DOT-OST-2012-0147-0319...Got it (09000064814dd151)
# 2021-05-27 11:31:09: Getting comment headers associated with document DOT-OST-2012-0147-0319...
#
# Found 0 comments...
# 2021-05-27 11:31:09: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document DOT-OST-2012-0147-0319----------------
#
# ******************************
# 2021-05-27 11:31:09: Getting comments for document DOT-OST-2012-0147-0247...
#
# 2021-05-27 11:31:09: Getting objectId for document DOT-OST-2012-0147-0247...Got it (0900006481429bca)
# 2021-05-27 11:31:10: Getting comment headers associated with document DOT-OST-2012-0147-0247...
#
# Found 26 comments...
# 2021-05-27 11:31:10: Inserting 26 records into database...
# 2021-05-27 11:31:11: Writing 26 records to comment_headers_113110.csv...Done
# 2021-05-27 11:31:11: Removing any duplicates in the CSV...
# 2021-05-27 11:31:11: Done. Removed 0 duplicate rows from comment_headers_113110.csv.
# 2021-05-27 11:31:11: Finished: approximately 26 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 11:31:11: Getting comments associated with document DOT-OST-2012-0147-0247...
#
# 2021-05-27 11:31:11: Gathering details for 26 comments...
# (Requests left: 500)
# (Requests left: 500)
# 2021-05-27 11:31:16: Inserting 26 records into database...
# 2021-05-27 11:31:16: Writing 26 records to DOT-OST-2012-0147.csv...Done
# 2021-05-27 11:31:16: Finished: 26 comments collected
#
# Done getting all 26 comments for document DOT-OST-2012-0147-0247----------------
#
# ******************************
# 2021-05-27 11:31:16: Getting comments for document DOT-OST-2012-0147-0290...
#
# 2021-05-27 11:31:16: Getting objectId for document DOT-OST-2012-0147-0290...Got it (09000064814bb8f6)
# 2021-05-27 11:31:16: Getting comment headers associated with document DOT-OST-2012-0147-0290...
#
# Found 0 comments...
# 2021-05-27 11:31:17: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document DOT-OST-2012-0147-0290----------------
#
# ******************************
# 2021-05-27 11:31:17: Getting comments for document DOT-OST-2012-0147-0278...
#
# 2021-05-27 11:31:17: Getting objectId for document DOT-OST-2012-0147-0278...Got it (090000648147a621)
# 2021-05-27 11:31:17: Getting comment headers associated with document DOT-OST-2012-0147-0278...
#
# Found 40 comments...
# 2021-05-27 11:31:18: Inserting 40 records into database...
# 2021-05-27 11:31:18: Writing 40 records to comment_headers_113117.csv...Done
# 2021-05-27 11:31:18: Removing any duplicates in the CSV...
# 2021-05-27 11:31:18: Done. Removed 0 duplicate rows from comment_headers_113117.csv.
# 2021-05-27 11:31:18: Finished: approximately 40 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 11:31:18: Getting comments associated with document DOT-OST-2012-0147-0278...
#
# 2021-05-27 11:31:18: Gathering details for 40 comments...
# 2021-05-27 11:31:26: Inserting 40 records into database...
# 2021-05-27 11:31:26: Writing 40 records to DOT-OST-2012-0147.csv...Done
# 2021-05-27 11:31:26: Finished: 40 comments collected
#
# Done getting all 40 comments for document DOT-OST-2012-0147-0278----------------
#
# ******************************
# 2021-05-27 11:31:26: Getting comments for document DOT-OST-2012-0147-0293...
#
# 2021-05-27 11:31:26: Getting objectId for document DOT-OST-2012-0147-0293...Got it (09000064814cbd66)
# 2021-05-27 11:31:26: Getting comment headers associated with document DOT-OST-2012-0147-0293...
#
# Found 0 comments...
# 2021-05-27 11:31:27: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document DOT-OST-2012-0147-0293----------------
#
# ******************************
# 2021-05-27 11:31:27: Getting comments for document DOT-OST-2012-0147-0003...
#
# 2021-05-27 11:31:27: Getting objectId for document DOT-OST-2012-0147-0003...Got it (0900006481109196)
# 2021-05-27 11:31:27: Getting comment headers associated with document DOT-OST-2012-0147-0003...
#
# Found 50 comments...
# 2021-05-27 11:31:28: Inserting 50 records into database...
# 2021-05-27 11:31:28: Writing 50 records to comment_headers_113127.csv...Done
# 2021-05-27 11:31:28: Removing any duplicates in the CSV...
# 2021-05-27 11:31:28: Done. Removed 0 duplicate rows from comment_headers_113127.csv.
# 2021-05-27 11:31:28: Finished: approximately 50 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 11:31:28: Getting comments associated with document DOT-OST-2012-0147-0003...
#
# 2021-05-27 11:31:28: Gathering details for 50 comments...
# (Requests left: 400)
# 2021-05-27 11:31:38: Inserting 50 records into database...
# 2021-05-27 11:31:38: Writing 50 records to DOT-OST-2012-0147.csv...Done
# 2021-05-27 11:31:38: Finished: 50 comments collected
#
# Done getting all 50 comments for document DOT-OST-2012-0147-0003----------------
#
# ******************************
# 2021-05-27 11:31:38: Getting comments for document DOT-OST-2012-0147-0289...
#
# 2021-05-27 11:31:38: Getting objectId for document DOT-OST-2012-0147-0289...Got it (09000064814bb8f4)
# 2021-05-27 11:31:38: Getting comment headers associated with document DOT-OST-2012-0147-0289...
#
# Found 0 comments...
# 2021-05-27 11:31:39: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document DOT-OST-2012-0147-0289----------------
#
# ******************************
# 2021-05-27 11:31:39: Getting comments for document DOT-OST-2012-0147-0329...
#
# 2021-05-27 11:31:39: Getting objectId for document DOT-OST-2012-0147-0329...Got it (09000064818a2b59)
# 2021-05-27 11:31:39: Getting comment headers associated with document DOT-OST-2012-0147-0329...
#
# Found 0 comments...
# 2021-05-27 11:31:39: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document DOT-OST-2012-0147-0329----------------
#
# ******************************
# 2021-05-27 11:31:39: Getting comments for document DOT-OST-2012-0147-0267...
#
# 2021-05-27 11:31:39: Getting objectId for document DOT-OST-2012-0147-0267...Got it (090000648145c12d)
# 2021-05-27 11:31:40: Getting comment headers associated with document DOT-OST-2012-0147-0267...
#
# Found 0 comments...
# 2021-05-27 11:31:40: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document DOT-OST-2012-0147-0267----------------
#
# ******************************
# 2021-05-27 11:31:40: Getting comments for document DOT-OST-2012-0147-0032...
#
# 2021-05-27 11:31:40: Getting objectId for document DOT-OST-2012-0147-0032...Got it (0900006481150293)
# 2021-05-27 11:31:40: Getting comment headers associated with document DOT-OST-2012-0147-0032...
#
# Found 123 comments...
# 2021-05-27 11:31:41: Inserting 123 records into database...
# 2021-05-27 11:31:41: Writing 123 records to comment_headers_113140.csv...Done
# 2021-05-27 11:31:41: Removing any duplicates in the CSV...
# 2021-05-27 11:31:41: Done. Removed 0 duplicate rows from comment_headers_113140.csv.
# 2021-05-27 11:31:41: Finished: approximately 123 comments collected
#
# Done getting comment IDs----------------
#
# 2021-05-27 11:31:41: Getting comments associated with document DOT-OST-2012-0147-0032...
#
# 2021-05-27 11:31:41: Gathering details for 123 comments...
# (Requests left: 300)
# (Requests left: 300)
# 2021-05-27 11:32:06: Inserting 123 records into database...
# 2021-05-27 11:32:06: Writing 123 records to DOT-OST-2012-0147.csv...Done
# 2021-05-27 11:32:06: Finished: 123 comments collected
#
# Done getting all 123 comments for document DOT-OST-2012-0147-0032----------------
#
# ******************************
# 2021-05-27 11:32:06: Getting comments for document DOT-OST-2012-0147-0238...
#
# 2021-05-27 11:32:06: Getting objectId for document DOT-OST-2012-0147-0238...Got it (09000064811a4959)
# 2021-05-27 11:32:06: Getting comment headers associated with document DOT-OST-2012-0147-0238...
#
# Found 0 comments...
# 2021-05-27 11:32:06: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document DOT-OST-2012-0147-0238----------------
#
# ******************************
# 2021-05-27 11:32:06: Getting comments for document DOT-OST-2012-0147-0244...
#
# 2021-05-27 11:32:06: Getting objectId for document DOT-OST-2012-0147-0244...Got it (09000064812395c6)
# 2021-05-27 11:32:07: Getting comment headers associated with document DOT-OST-2012-0147-0244...
#
# Found 0 comments...
# 2021-05-27 11:32:07: Finished: approximately 0 comments collected
#
# Done getting all 0 comments for document DOT-OST-2012-0147-0244----------------
#
# DONE retrieving all 314 comments from 15 document(s) for docket DOT-OST-2012-0147----------------

# %%
conn = sqlite3.connect("testdb.db")
cur = conn.cursor()
pd.read_sql_query("select count(*) from comments_detail where docketId='DOT-OST-2012-0147'", conn)
# Out:
#    count(*)
# 0       314

# %%
conn.close()
